# %%
import pennylane as qml
import numpy as np
import cirq
#use pytorch for the OMD implementation
import torch as torch
#optimistic Adam class in optim file
import optim

# %% [markdown]
# Any computational object that can apply quantum operations and return a measurement value is called a quantum device.
#
# In PennyLane, a device could be a hardware device (such as the IBM QX4, via the PennyLane-PQ plugin), or a software simulator (such as Strawberry Fields, via the PennyLane-SF plugin).

# %%
dev = qml.device('cirq.simulator', wires=1)

# %% [markdown]
# Unitary = arbitrary rotation

# %%
phi = np.pi / 6
theta = np.pi / 2
omega = np.pi / 7
angles = [phi,theta,omega]

def real(angles, **kwargs):
    qml.Rot(*angles, wires=0)

# %% [markdown]
# Generator

# %%
def generator(w, **kwargs):
    qml.RZ(w[0], wires=0)
    qml.RY(w[1], wires=0)
    qml.RZ(w[2], wires=0)

# %% [markdown]
# Discriminator

# %%
def discriminator(w):
    qml.RZ(w[0], wires=0)
    qml.RY(w[1], wires=0)
    qml.RZ(w[2], wires=0)

# %% [markdown]
# 2 nodes:  1 for data-discriminator
#           1 for generator-discriminator

# %%
@qml.qnode(dev, interface="torch", diff_method = 'parameter-shift')
def real_disc_circuit(angles, disc_weights):
    real(angles)
    discriminator(disc_weights[0:3])
    return qml.expval(qml.PauliZ(0))

@qml.qnode(dev, interface="torch", diff_method = 'parameter-shift')
def gen_disc_circuit(gen_weights, disc_weights):
    generator(gen_weights)
    discriminator(disc_weights[0:3])
    return qml.expval(qml.PauliZ(0))

# %% [markdown]
# Cost Functions

# %%
def prob_real_true(disc_weights):
    true_disc_output = real_disc_circuit(angles, disc_weights)
    # convert to probability
    prob_real_true = (true_disc_output + 1) / 2
    return prob_real_true


def prob_fake_true(gen_weights, disc_weights):
    fake_disc_output = gen_disc_circuit(gen_weights, disc_weights)
    # convert to probability
    prob_fake_true = (fake_disc_output + 1) / 2
    return prob_fake_true


def disc_cost(disc_weights, gen_weights):
    cost = prob_fake_true(gen_weights, disc_weights) - prob_real_true(disc_weights)
    return cost


def gen_cost(gen_weights, disc_weights):
    return -prob_fake_true(gen_weights, disc_weights)

# %% [markdown]
# initial weights

# %%
phi = np.pi / 6
theta = np.pi / 2
omega = np.pi / 7
np.random.seed(0)
eps = 1e-2
init_gen_weights = np.array([np.pi] + [0] * 2) + \
                   np.random.normal(scale=eps, size=(3,))
init_disc_weights = np.random.normal(size=(3,))

gen_weights_grad  = torch.tensor(init_gen_weights, requires_grad=True)
disc_weights_grad = torch.tensor(init_disc_weights, requires_grad=True)

# %% [markdown]
# Training

# %%
N = 100      #Number of training cycles
steps = 20 #Number of steps for discriminator training
ratio = 1/20  #disc/gen training ratio

for i in range (N):
    
    #training discriminator
    #OAdam only updates the parameters with requires_grad = True and doesn't change the other ones
    gen_weights_non_grad = torch.tensor(gen_weights_grad.detach().numpy(), requires_grad = False)
    #need an optimizer for both cases seperately
    opt = optim.OAdam([disc_weights_grad, gen_weights_non_grad], lr = 0.1)
    
    #los function
    def closure():
        opt.zero_grad()
        loss = disc_cost(disc_weights_grad, gen_weights_non_grad)
        loss.backward()
        return loss

    #do the discriminator training steps
    for j in range(steps):
        #use  step and not minimize
        opt.step(closure)
        if j % 5 == 0:
            cost_val = disc_cost(disc_weights_grad, gen_weights_non_grad).detach().numpy()
            print('Epoch  {}/{}, Cost: {}, Probability class real as real: {}'.format(j, steps, cost_val, prob_real_true(disc_weights_grad).detach().numpy()))

    
    print('discriminator trained')
    
    #training generator
    #switch requires_grad for both weight sets
    disc_weights_non_grad = torch.tensor(disc_weights_grad.detach().numpy(), requires_grad = False)
    gen_weights_grad = torch.tensor(gen_weights_non_grad.detach().numpy(), requires_grad = True)
    #define new optimizer
    opt = optim.OAdam([disc_weights_non_grad, gen_weights_grad], lr = 0.1)
    
    #generator loss
    def closure():
        opt.zero_grad()
        loss = gen_cost(gen_weights_grad, disc_weights_non_grad)
        loss.backward()
        return loss

    #do the optimization with steps*ratio
    for k in range(int(steps*ratio)):
        opt.step(closure)
        if k % 5 == 0:
            cost_val = gen_cost(gen_weights_grad, disc_weights_non_grad).detach().numpy()
            print('Epoch  {}/{}, Cost: {}, Probability class fake as real: {}'.format(k, steps*ratio, cost_val, prob_fake_true(gen_weights_grad, disc_weights_non_grad).detach().numpy()))

    
    #switch discriminator weights back to requires_grad
    disc_weights_grad = torch.tensor(disc_weights_non_grad.detach().numpy(), requires_grad = True)
    print('end of cycle', i)
    print('\n')
# Out:
# C:\Users\sarah\Downloads\optim.py:95: UserWarning: This overload of addcdiv_ is deprecated:
# 	addcdiv_(Number value, Tensor tensor1, Tensor tensor2)
# Consider using one of the following signatures instead:
# 	addcdiv_(Tensor tensor1, Tensor tensor2, *, Number value) (Triggered internally at  ..\torch\csrc\utils\python_arg_parser.cpp:1050.)
#   p.data.addcdiv_(step_size, exp_avg, exp_avg_sq.sqrt().add(group['eps']))
# Epoch  0/20, Cost: -0.6626259014010429, Probability class real as real: 0.9256928488612175
# Epoch  5/20, Cost: -0.7001638375222683, Probability class real as real: 0.8127418607473373
# Epoch  10/20, Cost: -0.6998931020498276, Probability class real as real: 0.812340259552002
# Epoch  15/20, Cost: -0.7057937160134315, Probability class real as real: 0.8553089052438736
# discriminator trained
# Epoch  0/1.0, Cost: -0.24021577090024948, Probability class fake as real: 0.24021577090024948
# end of cycle 0
#
#
# Epoch  0/20, Cost: -0.6285642758011818, Probability class real as real: 0.7848358079791069
# Epoch  5/20, Cost: -0.633650928735733, Probability class real as real: 0.820900022983551
# Epoch  10/20, Cost: -0.6337005198001862, Probability class real as real: 0.8159846141934395
# Epoch  15/20, Cost: -0.6337077766656876, Probability class real as real: 0.8169958516955376
# discriminator trained
# Epoch  0/1.0, Cost: -0.26904481649398804, Probability class fake as real: 0.26904481649398804
# end of cycle 1
#
#
# Epoch  0/20, Cost: -0.5465445071458817, Probability class real as real: 0.7321674227714539
# Epoch  5/20, Cost: -0.5509854033589363, Probability class real as real: 0.7781660556793213
# Epoch  10/20, Cost: -0.5509981960058212, Probability class real as real: 0.7749201655387878
# Epoch  15/20, Cost: -0.5509990453720093, Probability class real as real: 0.7756303250789642
# discriminator trained
# Epoch  0/1.0, Cost: -0.31164926290512085, Probability class fake as real: 0.31164926290512085
# end of cycle 2
#
#
# Epoch  0/20, Cost: -0.46556292474269867, Probability class real as real: 0.6843066215515137
# Epoch  5/20, Cost: -0.4686305969953537, Probability class real as real: 0.7343737035989761
# Epoch  10/20, Cost: -0.4686948359012604, Probability class real as real: 0.7347406893968582
# Epoch  15/20, Cost: -0.46871842443943024, Probability class real as real: 0.7344582676887512
# discriminator trained
# Epoch  0/1.0, Cost: -0.365189865231514, Probability class fake as real: 0.365189865231514
# end of cycle 3
#
#
# Epoch  0/20, Cost: -0.3727806955575943, Probability class real as real: 0.6472698003053665
# Epoch  5/20, Cost: -0.37421131134033203, Probability class real as real: 0.6888128072023392
# Epoch  10/20, Cost: -0.3744404762983322, Probability class real as real: 0.6861347705125809
# Epoch  15/20, Cost: -0.37442252039909363, Probability class real as real: 0.6878324598073959
# discriminator trained
# Epoch  0/1.0, Cost: -0.4096674621105194, Probability class fake as real: 0.4096674621105194
# end of cycle 4
#
#
# Epoch  0/20, Cost: -0.28048937022686005, Probability class real as real: 0.5918734669685364
# Epoch  5/20, Cost: -0.28894655406475067, Probability class real as real: 0.6626458764076233
# Epoch  10/20, Cost: -0.2887088656425476, Probability class real as real: 0.622888058423996
# Epoch  15/20, Cost: -0.2888072282075882, Probability class real as real: 0.6250717788934708
# discriminator trained
# Epoch  0/1.0, Cost: -0.4682605564594269, Probability class fake as real: 0.4682605564594269
# end of cycle 5
#
#
# Epoch  0/20, Cost: -0.17996355891227722, Probability class real as real: 0.5782915502786636
# Epoch  5/20, Cost: -0.1813332587480545, Probability class real as real: 0.5438963770866394
# Epoch  10/20, Cost: -0.18290546536445618, Probability class real as real: 0.6079622656106949
# Epoch  15/20, Cost: -0.1833105981349945, Probability class real as real: 0.6012559682130814
# discriminator trained
# Epoch  0/1.0, Cost: -0.5081607550382614, Probability class fake as real: 0.5081607550382614
# end of cycle 6
#
#
# Epoch  0/20, Cost: -0.08292561769485474, Probability class real as real: 0.5019143968820572
# Epoch  5/20, Cost: -0.09003187716007233, Probability class real as real: 0.3626485764980316
# Epoch  10/20, Cost: -0.10470768809318542, Probability class real as real: 0.3705182373523712
# Epoch  15/20, Cost: -0.11456204950809479, Probability class real as real: 0.503747820854187
# discriminator trained
# Epoch  0/1.0, Cost: -0.6341040730476379, Probability class fake as real: 0.6341040730476379
# end of cycle 7
#
#
# Epoch  0/20, Cost: 0.02333720028400421, Probability class real as real: 0.6416467577219009
# Epoch  5/20, Cost: 0.017647624015808105, Probability class real as real: 0.5570816993713379
# Epoch  10/20, Cost: 0.013623863458633423, Probability class real as real: 0.3177131563425064
# Epoch  15/20, Cost: 0.002020508050918579, Probability class real as real: 0.1613679826259613
# discriminator trained
# Epoch  0/1.0, Cost: -0.3030475080013275, Probability class fake as real: 0.3030475080013275
# end of cycle 8
#
#
# Epoch  0/20, Cost: 0.06563015282154083, Probability class real as real: 0.12900744378566742
# Epoch  5/20, Cost: -0.034968484193086624, Probability class real as real: 0.08637502416968346
# Epoch  10/20, Cost: -0.10451966524124146, Probability class real as real: 0.27119600772857666
# Epoch  15/20, Cost: -0.120205357670784, Probability class real as real: 0.4482807517051697
# discriminator trained
# Epoch  0/1.0, Cost: -0.47690117359161377, Probability class fake as real: 0.47690117359161377
# end of cycle 9
#
#
# Epoch  0/20, Cost: -0.01891346275806427, Probability class real as real: 0.5578285753726959
# Epoch  5/20, Cost: -0.02521553635597229, Probability class real as real: 0.5390814542770386
# Epoch  10/20, Cost: -0.025269389152526855, Probability class real as real: 0.4618070274591446
# Epoch  15/20, Cost: -0.025250881910324097, Probability class real as real: 0.5149611383676529
# discriminator trained
# Epoch  0/1.0, Cost: -0.6421695798635483, Probability class fake as real: 0.6421695798635483
# end of cycle 10
#
#
# Epoch  0/20, Cost: 0.09952838718891144, Probability class real as real: 0.6246469467878342
# Epoch  5/20, Cost: 0.032040711492300034, Probability class real as real: 0.8633467555046082
# Epoch  10/20, Cost: -0.04726160690188408, Probability class real as real: 0.8854777477681637
# Epoch  15/20, Cost: -0.0897284746170044, Probability class real as real: 0.7085133194923401
# discriminator trained
# Epoch  0/1.0, Cost: -0.6097468882799149, Probability class fake as real: 0.6097468882799149
# end of cycle 11
#
#
# Epoch  0/20, Cost: 0.01677630841732025, Probability class real as real: 0.5115011185407639
# Epoch  5/20, Cost: 0.008890151977539062, Probability class real as real: 0.28955820202827454
# Epoch  10/20, Cost: -0.006684035062789917, Probability class real as real: 0.2943887710571289
# Epoch  15/20, Cost: -0.01985032856464386, Probability class real as real: 0.4905017018318176
# discriminator trained
# Epoch  0/1.0, Cost: -0.7011614888906479, Probability class fake as real: 0.7011614888906479
# end of cycle 12
#
#
# Epoch  0/20, Cost: 0.08264847844839096, Probability class real as real: 0.6992936730384827
# Epoch  5/20, Cost: 0.0025914348661899567, Probability class real as real: 0.889802448451519
# Epoch  10/20, Cost: -0.06778818368911743, Probability class real as real: 0.825641855597496
# Epoch  15/20, Cost: -0.09211736917495728, Probability class real as real: 0.6408265680074692
# discriminator trained
# Epoch  0/1.0, Cost: -0.5842639058828354, Probability class fake as real: 0.5842639058828354
# end of cycle 13
#
#
# Epoch  0/20, Cost: 0.016352131962776184, Probability class real as real: 0.48785628378391266
# Epoch  5/20, Cost: 0.006105169653892517, Probability class real as real: 0.30984407663345337
# Epoch  10/20, Cost: -0.009527772665023804, Probability class real as real: 0.3824268579483032
# Epoch  15/20, Cost: -0.02049332857131958, Probability class real as real: 0.5713764131069183
# discriminator trained
# Epoch  0/1.0, Cost: -0.7148376405239105, Probability class fake as real: 0.7148376405239105
# end of cycle 14
#
#
# Epoch  0/20, Cost: 0.08320878446102142, Probability class real as real: 0.7125322818756104
# Epoch  5/20, Cost: 0.003022231161594391, Probability class real as real: 0.9028696045279503
# Epoch  10/20, Cost: -0.06809961050748825, Probability class real as real: 0.837689995765686
# Epoch  15/20, Cost: -0.09328912198543549, Probability class real as real: 0.6509100198745728
# discriminator trained
# Epoch  0/1.0, Cost: -0.5923096835613251, Probability class fake as real: 0.5923096835613251
# end of cycle 15
#
#
# Epoch  0/20, Cost: 0.01659110188484192, Probability class real as real: 0.49963948130607605
# Epoch  5/20, Cost: 0.00685746967792511, Probability class real as real: 0.3118697851896286
# Epoch  10/20, Cost: -0.008748412132263184, Probability class real as real: 0.36960069835186005
# Epoch  15/20, Cost: -0.02017061412334442, Probability class real as real: 0.5612727105617523
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145194262266159, Probability class fake as real: 0.7145194262266159
# end of cycle 16
#
#
# Epoch  0/20, Cost: 0.08201078325510025, Probability class real as real: 0.7129944860935211
# Epoch  5/20, Cost: 0.0013702288269996643, Probability class real as real: 0.8999555222690105
# Epoch  10/20, Cost: -0.06890270113945007, Probability class real as real: 0.8308626264333725
# Epoch  15/20, Cost: -0.09299905598163605, Probability class real as real: 0.6451859325170517
# discriminator trained
# Epoch  0/1.0, Cost: -0.5893710404634476, Probability class fake as real: 0.5893710404634476
# end of cycle 17
#
#
# Epoch  0/20, Cost: 0.016508713364601135, Probability class real as real: 0.4958193600177765
# Epoch  5/20, Cost: 0.006560534238815308, Probability class real as real: 0.3123433291912079
# Epoch  10/20, Cost: -0.009045198559761047, Probability class real as real: 0.376486673951149
# Epoch  15/20, Cost: -0.020269975066184998, Probability class real as real: 0.5666044652462006
# discriminator trained
# Epoch  0/1.0, Cost: -0.7144932597875595, Probability class fake as real: 0.7144932597875595
# end of cycle 18
#
#
# Epoch  0/20, Cost: 0.08240354061126709, Probability class real as real: 0.7127145975828171
# Epoch  5/20, Cost: 0.001909881830215454, Probability class real as real: 0.9007963314652443
# Epoch  10/20, Cost: -0.06863764673471451, Probability class real as real: 0.8329946547746658
# Epoch  15/20, Cost: -0.09308336675167084, Probability class real as real: 0.6469659358263016
# discriminator trained
# Epoch  0/1.0, Cost: -0.590259239077568, Probability class fake as real: 0.590259239077568
# end of cycle 19
#
#
# Epoch  0/20, Cost: 0.01653324067592621, Probability class real as real: 0.4969564825296402
# Epoch  5/20, Cost: 0.006650611758232117, Probability class real as real: 0.3121527284383774
# Epoch  10/20, Cost: -0.008956179022789001, Probability class real as real: 0.3743596822023392
# Epoch  15/20, Cost: -0.020240560173988342, Probability class real as real: 0.5649987161159515
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145319879055023, Probability class fake as real: 0.7145319879055023
# end of cycle 20
#
#
# Epoch  0/20, Cost: 0.08228551596403122, Probability class real as real: 0.7128294706344604
# Epoch  5/20, Cost: 0.0017460286617279053, Probability class real as real: 0.9005689918994904
# Epoch  10/20, Cost: -0.06871973723173141, Probability class real as real: 0.8323699161410332
# Epoch  15/20, Cost: -0.0930602103471756, Probability class real as real: 0.6464433372020721
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900050699710846, Probability class fake as real: 0.5900050699710846
# end of cycle 21
#
#
# Epoch  0/20, Cost: 0.01652638614177704, Probability class real as real: 0.49663445353507996
# Epoch  5/20, Cost: 0.006625086069107056, Probability class real as real: 0.3122137486934662
# Epoch  10/20, Cost: -0.008981198072433472, Probability class real as real: 0.3749801814556122
# Epoch  15/20, Cost: -0.020248398184776306, Probability class real as real: 0.5654689222574234
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145217955112457, Probability class fake as real: 0.7145217955112457
# end of cycle 22
#
#
# Epoch  0/20, Cost: 0.08231927454471588, Probability class real as real: 0.7127972841262817
# Epoch  5/20, Cost: 0.0017926692962646484, Probability class real as real: 0.9006338343024254
# Epoch  10/20, Cost: -0.0686962753534317, Probability class real as real: 0.8325470238924026
# Epoch  15/20, Cost: -0.09306670725345612, Probability class real as real: 0.6465914398431778
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900776237249374, Probability class fake as real: 0.5900776237249374
# end of cycle 23
#
#
# Epoch  0/20, Cost: 0.01652856171131134, Probability class real as real: 0.49672630429267883
# Epoch  5/20, Cost: 0.00663265585899353, Probability class real as real: 0.31219758093357086
# Epoch  10/20, Cost: -0.008973568677902222, Probability class real as real: 0.3748064637184143
# Epoch  15/20, Cost: -0.02024562656879425, Probability class real as real: 0.5653372257947922
# discriminator trained
# Epoch  0/1.0, Cost: -0.714524656534195, Probability class fake as real: 0.714524656534195
# end of cycle 24
#
#
# Epoch  0/20, Cost: 0.08231014758348465, Probability class real as real: 0.7128060013055801
# Epoch  5/20, Cost: 0.0017798282206058502, Probability class real as real: 0.9006153121590614
# Epoch  10/20, Cost: -0.06870278716087341, Probability class real as real: 0.8324970230460167
# Epoch  15/20, Cost: -0.0930648148059845, Probability class real as real: 0.646549865603447
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900576114654541, Probability class fake as real: 0.5900576114654541
# end of cycle 25
#
#
# Epoch  0/20, Cost: 0.016528040170669556, Probability class real as real: 0.49670085310935974
# Epoch  5/20, Cost: 0.006630837917327881, Probability class real as real: 0.3122006356716156
# Epoch  10/20, Cost: -0.00897526741027832, Probability class real as real: 0.3748509883880615
# Epoch  15/20, Cost: -0.020246043801307678, Probability class real as real: 0.5653716027736664
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145254611968994, Probability class fake as real: 0.7145254611968994
# end of cycle 26
#
#
# Epoch  0/20, Cost: 0.08231303095817566, Probability class real as real: 0.7128049582242966
# Epoch  5/20, Cost: 0.001783519983291626, Probability class real as real: 0.9006217829883099
# Epoch  10/20, Cost: -0.06870098412036896, Probability class real as real: 0.8325120285153389
# Epoch  15/20, Cost: -0.09306544065475464, Probability class real as real: 0.6465624272823334
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900642573833466, Probability class fake as real: 0.5900642573833466
# end of cycle 27
#
#
# Epoch  0/20, Cost: 0.016528308391571045, Probability class real as real: 0.49670960009098053
# Epoch  5/20, Cost: 0.0066316574811935425, Probability class real as real: 0.31220024824142456
# Epoch  10/20, Cost: -0.008974194526672363, Probability class real as real: 0.37483687698841095
# Epoch  15/20, Cost: -0.020245492458343506, Probability class real as real: 0.5653610676527023
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145258635282516, Probability class fake as real: 0.7145258635282516
# end of cycle 28
#
#
# Epoch  0/20, Cost: 0.08231250196695328, Probability class real as real: 0.7128055691719055
# Epoch  5/20, Cost: 0.0017826594412326813, Probability class real as real: 0.900620236992836
# Epoch  10/20, Cost: -0.06870149821043015, Probability class real as real: 0.8325080648064613
# Epoch  15/20, Cost: -0.09306539595127106, Probability class real as real: 0.6465593129396439
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900633335113525, Probability class fake as real: 0.5900633335113525
# end of cycle 29
#
#
# Epoch  0/20, Cost: 0.016528308391571045, Probability class real as real: 0.49670809507369995
# Epoch  5/20, Cost: 0.00663168728351593, Probability class real as real: 0.3122006952762604
# Epoch  10/20, Cost: -0.008974194526672363, Probability class real as real: 0.3748406618833542
# Epoch  15/20, Cost: -0.020245090126991272, Probability class real as real: 0.5653636455535889
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145255208015442, Probability class fake as real: 0.7145255208015442
# end of cycle 30
#
#
# Epoch  0/20, Cost: 0.08231321722269058, Probability class real as real: 0.7128046751022339
# Epoch  5/20, Cost: 0.0017833523452281952, Probability class real as real: 0.9006203338503838
# Epoch  10/20, Cost: -0.06870109587907791, Probability class real as real: 0.8325091749429703
# Epoch  15/20, Cost: -0.09306536614894867, Probability class real as real: 0.6465602517127991
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900640040636063, Probability class fake as real: 0.5900640040636063
# end of cycle 31
#
#
# Epoch  0/20, Cost: 0.01652832329273224, Probability class real as real: 0.49670882523059845
# Epoch  5/20, Cost: 0.006631970405578613, Probability class real as real: 0.31220006942749023
# Epoch  10/20, Cost: -0.008973553776741028, Probability class real as real: 0.3748380243778229
# Epoch  15/20, Cost: -0.020244672894477844, Probability class real as real: 0.5653616487979889
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145262062549591, Probability class fake as real: 0.7145262062549591
# end of cycle 32
#
#
# Epoch  0/20, Cost: 0.08231335878372192, Probability class real as real: 0.7128051966428757
# Epoch  5/20, Cost: 0.0017834454774856567, Probability class real as real: 0.9006207101047039
# Epoch  10/20, Cost: -0.0687011182308197, Probability class real as real: 0.8325096070766449
# Epoch  15/20, Cost: -0.09306538105010986, Probability class real as real: 0.6465608030557632
# discriminator trained
# Epoch  0/1.0, Cost: -0.59006467461586, Probability class fake as real: 0.59006467461586
# end of cycle 33
#
#
# Epoch  0/20, Cost: 0.016528472304344177, Probability class real as real: 0.4967096596956253
# Epoch  5/20, Cost: 0.006632328033447266, Probability class real as real: 0.31219837069511414
# Epoch  10/20, Cost: -0.008973151445388794, Probability class real as real: 0.37483273446559906
# Epoch  15/20, Cost: -0.02024441957473755, Probability class real as real: 0.5653569400310516
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145242542028427, Probability class fake as real: 0.7145242542028427
# end of cycle 34
#
#
# Epoch  0/20, Cost: 0.08231403678655624, Probability class real as real: 0.7128027081489563
# Epoch  5/20, Cost: 0.0017841644585132599, Probability class real as real: 0.9006195031106472
# Epoch  10/20, Cost: -0.0687006413936615, Probability class real as real: 0.8325097933411598
# Epoch  15/20, Cost: -0.09306514263153076, Probability class real as real: 0.646560937166214
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900646150112152, Probability class fake as real: 0.5900646150112152
# end of cycle 35
#
#
# Epoch  0/20, Cost: 0.016528695821762085, Probability class real as real: 0.4967091381549835
# Epoch  5/20, Cost: 0.006632566452026367, Probability class real as real: 0.3121989965438843
# Epoch  10/20, Cost: -0.008972898125648499, Probability class real as real: 0.3748345375061035
# Epoch  15/20, Cost: -0.02024400234222412, Probability class real as real: 0.5653589516878128
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145263254642487, Probability class fake as real: 0.7145263254642487
# end of cycle 36
#
#
# Epoch  0/20, Cost: 0.08231425285339355, Probability class real as real: 0.7128044664859772
# Epoch  5/20, Cost: 0.0017843134701251984, Probability class real as real: 0.9006209522485733
# Epoch  10/20, Cost: -0.06870090216398239, Probability class real as real: 0.8325108587741852
# Epoch  15/20, Cost: -0.09306541085243225, Probability class real as real: 0.6465620547533035
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900659412145615, Probability class fake as real: 0.5900659412145615
# end of cycle 37
#
#
# Epoch  0/20, Cost: 0.01652871072292328, Probability class real as real: 0.4967110604047775
# Epoch  5/20, Cost: 0.006632819771766663, Probability class real as real: 0.31219975650310516
# Epoch  10/20, Cost: -0.00897236168384552, Probability class real as real: 0.37483398616313934
# Epoch  15/20, Cost: -0.020243659615516663, Probability class real as real: 0.5653593093156815
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145277708768845, Probability class fake as real: 0.7145277708768845
# end of cycle 38
#
#
# Epoch  0/20, Cost: 0.08231442421674728, Probability class real as real: 0.7128057330846786
# Epoch  5/20, Cost: 0.001784045249223709, Probability class real as real: 0.9006215892732143
# Epoch  10/20, Cost: -0.06870105862617493, Probability class real as real: 0.8325106054544449
# Epoch  15/20, Cost: -0.09306542575359344, Probability class real as real: 0.6465618461370468
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900664776563644, Probability class fake as real: 0.5900664776563644
# end of cycle 39
#
#
# Epoch  0/20, Cost: 0.016529008746147156, Probability class real as real: 0.4967116564512253
# Epoch  5/20, Cost: 0.006632983684539795, Probability class real as real: 0.3121998459100723
# Epoch  10/20, Cost: -0.00897197425365448, Probability class real as real: 0.3748326748609543
# Epoch  15/20, Cost: -0.020243287086486816, Probability class real as real: 0.5653578191995621
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145272791385651, Probability class fake as real: 0.7145272791385651
# end of cycle 40
#
#
# Epoch  0/20, Cost: 0.08231465518474579, Probability class real as real: 0.7128050774335861
# Epoch  5/20, Cost: 0.0017844438552856445, Probability class real as real: 0.9006212018430233
# Epoch  10/20, Cost: -0.06870093196630478, Probability class real as real: 0.832510694861412
# Epoch  15/20, Cost: -0.09306541085243225, Probability class real as real: 0.6465620994567871
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900667905807495, Probability class fake as real: 0.5900667905807495
# end of cycle 41
#
#
# Epoch  0/20, Cost: 0.01652906835079193, Probability class real as real: 0.49671192467212677
# Epoch  5/20, Cost: 0.006633400917053223, Probability class real as real: 0.31219886243343353
# Epoch  10/20, Cost: -0.008971571922302246, Probability class real as real: 0.374830037355423
# Epoch  15/20, Cost: -0.02024286985397339, Probability class real as real: 0.5653557032346725
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145280092954636, Probability class fake as real: 0.7145280092954636
# end of cycle 42
#
#
# Epoch  0/20, Cost: 0.08231496810913086, Probability class real as real: 0.7128055393695831
# Epoch  5/20, Cost: 0.0017845965921878815, Probability class real as real: 0.9006216935813427
# Epoch  10/20, Cost: -0.06870085000991821, Probability class real as real: 0.8325111716985703
# Epoch  15/20, Cost: -0.09306536614894867, Probability class real as real: 0.6465625464916229
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900672525167465, Probability class fake as real: 0.5900672525167465
# end of cycle 43
#
#
# Epoch  0/20, Cost: 0.016529157757759094, Probability class real as real: 0.4967125654220581
# Epoch  5/20, Cost: 0.006633579730987549, Probability class real as real: 0.3121991604566574
# Epoch  10/20, Cost: -0.008971244096755981, Probability class real as real: 0.37482988834381104
# Epoch  15/20, Cost: -0.020242631435394287, Probability class real as real: 0.565356120467186
# discriminator trained
# Epoch  0/1.0, Cost: -0.714528352022171, Probability class fake as real: 0.714528352022171
# end of cycle 44
#
#
# Epoch  0/20, Cost: 0.08231524378061295, Probability class real as real: 0.7128056585788727
# Epoch  5/20, Cost: 0.0017848312854766846, Probability class real as real: 0.9006219282746315
# Epoch  10/20, Cost: -0.06870073825120926, Probability class real as real: 0.8325116112828255
# Epoch  15/20, Cost: -0.09306536614894867, Probability class real as real: 0.6465630382299423
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900682210922241, Probability class fake as real: 0.5900682210922241
# end of cycle 45
#
#
# Epoch  0/20, Cost: 0.01652926206588745, Probability class real as real: 0.4967135339975357
# Epoch  5/20, Cost: 0.006633877754211426, Probability class real as real: 0.31219911575317383
# Epoch  10/20, Cost: -0.008970558643341064, Probability class real as real: 0.3748278170824051
# Epoch  15/20, Cost: -0.020242199301719666, Probability class real as real: 0.565353736281395
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145273685455322, Probability class fake as real: 0.7145273685455322
# end of cycle 46
#
#
# Epoch  0/20, Cost: 0.08231576532125473, Probability class real as real: 0.7128041237592697
# Epoch  5/20, Cost: 0.001785431057214737, Probability class real as real: 0.9006209969520569
# Epoch  10/20, Cost: -0.06870045512914658, Probability class real as real: 0.8325114697217941
# Epoch  15/20, Cost: -0.09306526184082031, Probability class real as real: 0.6465629041194916
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900680869817734, Probability class fake as real: 0.5900680869817734
# end of cycle 47
#
#
# Epoch  0/20, Cost: 0.016529276967048645, Probability class real as real: 0.49671319127082825
# Epoch  5/20, Cost: 0.006634116172790527, Probability class real as real: 0.31219905614852905
# Epoch  10/20, Cost: -0.008970409631729126, Probability class real as real: 0.3748287409543991
# Epoch  15/20, Cost: -0.020242005586624146, Probability class real as real: 0.5653549879789352
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145282328128815, Probability class fake as real: 0.7145282328128815
# end of cycle 48
#
#
# Epoch  0/20, Cost: 0.082316093146801, Probability class real as real: 0.7128046154975891
# Epoch  5/20, Cost: 0.0017856433987617493, Probability class real as real: 0.9006216675043106
# Epoch  10/20, Cost: -0.0687003955245018, Probability class real as real: 0.832512192428112
# Epoch  15/20, Cost: -0.09306538105010986, Probability class real as real: 0.646563783288002
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900689214468002, Probability class fake as real: 0.5900689214468002
# end of cycle 49
#
#
# Epoch  0/20, Cost: 0.016529321670532227, Probability class real as real: 0.496714323759079
# Epoch  5/20, Cost: 0.006634369492530823, Probability class real as real: 0.31219831109046936
# Epoch  10/20, Cost: -0.008970022201538086, Probability class real as real: 0.37482529878616333
# Epoch  15/20, Cost: -0.020241573452949524, Probability class real as real: 0.5653521865606308
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145287841558456, Probability class fake as real: 0.7145287841558456
# end of cycle 50
#
#
# Epoch  0/20, Cost: 0.0823163390159607, Probability class real as real: 0.7128051072359085
# Epoch  5/20, Cost: 0.0017857104539871216, Probability class real as real: 0.9006220325827599
# Epoch  10/20, Cost: -0.06870041787624359, Probability class real as real: 0.8325125053524971
# Epoch  15/20, Cost: -0.09306538105010986, Probability class real as real: 0.6465640068054199
# discriminator trained
# Epoch  0/1.0, Cost: -0.590069591999054, Probability class fake as real: 0.590069591999054
# end of cycle 51
#
#
# Epoch  0/20, Cost: 0.01652941107749939, Probability class real as real: 0.49671508371829987
# Epoch  5/20, Cost: 0.006634637713432312, Probability class real as real: 0.3121993988752365
# Epoch  10/20, Cost: -0.008969470858573914, Probability class real as real: 0.3748263418674469
# Epoch  15/20, Cost: -0.020241186022758484, Probability class real as real: 0.5653528869152069
# discriminator trained
# Epoch  0/1.0, Cost: -0.714528813958168, Probability class fake as real: 0.714528813958168
# end of cycle 52
#
#
# Epoch  0/20, Cost: 0.08231654018163681, Probability class real as real: 0.7128047347068787
# Epoch  5/20, Cost: 0.0017860010266304016, Probability class real as real: 0.9006217606365681
# Epoch  10/20, Cost: -0.06870037317276001, Probability class real as real: 0.8325125053524971
# Epoch  15/20, Cost: -0.0930652916431427, Probability class real as real: 0.6465642005205154
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900699198246002, Probability class fake as real: 0.5900699198246002
# end of cycle 53
#
#
# Epoch  0/20, Cost: 0.01652964949607849, Probability class real as real: 0.49671539664268494
# Epoch  5/20, Cost: 0.006634846329689026, Probability class real as real: 0.3121984302997589
# Epoch  10/20, Cost: -0.008969157934188843, Probability class real as real: 0.37482377886772156
# Epoch  15/20, Cost: -0.020240873098373413, Probability class real as real: 0.5653516203165054
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145299911499023, Probability class fake as real: 0.7145299911499023
# end of cycle 54
#
#
# Epoch  0/20, Cost: 0.08231692016124725, Probability class real as real: 0.7128055393695831
# Epoch  5/20, Cost: 0.0017861388623714447, Probability class real as real: 0.9006225541234016
# Epoch  10/20, Cost: -0.06870052963495255, Probability class real as real: 0.8325131013989449
# Epoch  15/20, Cost: -0.09306539595127106, Probability class real as real: 0.646564781665802
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900707095861435, Probability class fake as real: 0.5900707095861435
# end of cycle 55
#
#
# Epoch  0/20, Cost: 0.01652979850769043, Probability class real as real: 0.4967163950204849
# Epoch  5/20, Cost: 0.00663524866104126, Probability class real as real: 0.31219764053821564
# Epoch  10/20, Cost: -0.00896868109703064, Probability class real as real: 0.37482036650180817
# Epoch  15/20, Cost: -0.020240485668182373, Probability class real as real: 0.5653483271598816
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145289033651352, Probability class fake as real: 0.7145289033651352
# end of cycle 56
#
#
# Epoch  0/20, Cost: 0.0823172777891159, Probability class real as real: 0.712804302573204
# Epoch  5/20, Cost: 0.0017865374684333801, Probability class real as real: 0.9006218761205673
# Epoch  10/20, Cost: -0.0687001571059227, Probability class real as real: 0.8325131386518478
# Epoch  15/20, Cost: -0.09306526184082031, Probability class real as real: 0.6465649157762527
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900709331035614, Probability class fake as real: 0.5900709331035614
# end of cycle 57
#
#
# Epoch  0/20, Cost: 0.016529887914657593, Probability class real as real: 0.4967164248228073
# Epoch  5/20, Cost: 0.006635382771492004, Probability class real as real: 0.3121979981660843
# Epoch  10/20, Cost: -0.00896841287612915, Probability class real as real: 0.3748210221529007
# Epoch  15/20, Cost: -0.02024005353450775, Probability class real as real: 0.565348356962204
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145281136035919, Probability class fake as real: 0.7145281136035919
# end of cycle 58
#
#
# Epoch  0/20, Cost: 0.08231783658266068, Probability class real as real: 0.712803065776825
# Epoch  5/20, Cost: 0.0017870664596557617, Probability class real as real: 0.9006214812397957
# Epoch  10/20, Cost: -0.06869994848966599, Probability class real as real: 0.8325137346982956
# Epoch  15/20, Cost: -0.0930652916431427, Probability class real as real: 0.6465655416250229
# discriminator trained
# Epoch  0/1.0, Cost: -0.590071439743042, Probability class fake as real: 0.590071439743042
# end of cycle 59
#
#
# Epoch  0/20, Cost: 0.016529887914657593, Probability class real as real: 0.49671684205532074
# Epoch  5/20, Cost: 0.006635606288909912, Probability class real as real: 0.31219764053821564
# Epoch  10/20, Cost: -0.00896790623664856, Probability class real as real: 0.37481965124607086
# Epoch  15/20, Cost: -0.020239651203155518, Probability class real as real: 0.5653476864099503
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145295888185501, Probability class fake as real: 0.7145295888185501
# end of cycle 60
#
#
# Epoch  0/20, Cost: 0.08231810480356216, Probability class real as real: 0.712804302573204
# Epoch  5/20, Cost: 0.0017871074378490448, Probability class real as real: 0.9006223902106285
# Epoch  10/20, Cost: -0.0686999037861824, Probability class real as real: 0.8325141221284866
# Epoch  15/20, Cost: -0.09306538105010986, Probability class real as real: 0.6465660482645035
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900721698999405, Probability class fake as real: 0.5900721698999405
# end of cycle 61
#
#
# Epoch  0/20, Cost: 0.016530007123947144, Probability class real as real: 0.4967178553342819
# Epoch  5/20, Cost: 0.006635949015617371, Probability class real as real: 0.3121970444917679
# Epoch  10/20, Cost: -0.008967623114585876, Probability class real as real: 0.37481676042079926
# Epoch  15/20, Cost: -0.020239323377609253, Probability class real as real: 0.565345823764801
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145302891731262, Probability class fake as real: 0.7145302891731262
# end of cycle 62
#
#
# Epoch  0/20, Cost: 0.08231835067272186, Probability class real as real: 0.7128046751022339
# Epoch  5/20, Cost: 0.0017873495817184448, Probability class real as real: 0.900622796267271
# Epoch  10/20, Cost: -0.06869982928037643, Probability class real as real: 0.8325143679976463
# Epoch  15/20, Cost: -0.09306532144546509, Probability class real as real: 0.6465662270784378
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900727659463882, Probability class fake as real: 0.5900727659463882
# end of cycle 63
#
#
# Epoch  0/20, Cost: 0.016530171036720276, Probability class real as real: 0.49671870470046997
# Epoch  5/20, Cost: 0.0066362470388412476, Probability class real as real: 0.31219692528247833
# Epoch  10/20, Cost: -0.008967220783233643, Probability class real as real: 0.3748151808977127
# Epoch  15/20, Cost: -0.020238935947418213, Probability class real as real: 0.5653448551893234
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145315259695053, Probability class fake as real: 0.7145315259695053
# end of cycle 64
#
#
# Epoch  0/20, Cost: 0.08231869339942932, Probability class real as real: 0.7128056287765503
# Epoch  5/20, Cost: 0.0017874203622341156, Probability class real as real: 0.9006235189735889
# Epoch  10/20, Cost: -0.0686999186873436, Probability class real as real: 0.8325150161981583
# Epoch  15/20, Cost: -0.09306532144546509, Probability class real as real: 0.646566852927208
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900736600160599, Probability class fake as real: 0.5900736600160599
# end of cycle 65
#
#
# Epoch  0/20, Cost: 0.016530200839042664, Probability class real as real: 0.49671973288059235
# Epoch  5/20, Cost: 0.006636574864387512, Probability class real as real: 0.31219664216041565
# Epoch  10/20, Cost: -0.008966699242591858, Probability class real as real: 0.37481309473514557
# Epoch  15/20, Cost: -0.02023857831954956, Probability class real as real: 0.5653429627418518
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145310342311859, Probability class fake as real: 0.7145310342311859
# end of cycle 66
#
#
# Epoch  0/20, Cost: 0.08231887966394424, Probability class real as real: 0.7128049433231354
# Epoch  5/20, Cost: 0.001787666231393814, Probability class real as real: 0.9006230942904949
# Epoch  10/20, Cost: -0.06869979947805405, Probability class real as real: 0.8325148671865463
# Epoch  15/20, Cost: -0.0930653065443039, Probability class real as real: 0.6465668231248856
# discriminator trained
# Epoch  0/1.0, Cost: -0.590073898434639, Probability class fake as real: 0.590073898434639
# end of cycle 67
#
#
# Epoch  0/20, Cost: 0.016530349850654602, Probability class real as real: 0.49671976268291473
# Epoch  5/20, Cost: 0.006636723875999451, Probability class real as real: 0.31219740211963654
# Epoch  10/20, Cost: -0.008966445922851562, Probability class real as real: 0.37481462955474854
# Epoch  15/20, Cost: -0.020238250494003296, Probability class real as real: 0.56534343957901
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145302593708038, Probability class fake as real: 0.7145302593708038
# end of cycle 68
#
#
# Epoch  0/20, Cost: 0.08231945335865021, Probability class real as real: 0.7128037512302399
# Epoch  5/20, Cost: 0.001788068562746048, Probability class real as real: 0.9006226323544979
# Epoch  10/20, Cost: -0.06869958341121674, Probability class real as real: 0.832515150308609
# Epoch  15/20, Cost: -0.09306523203849792, Probability class real as real: 0.6465672552585602
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900743007659912, Probability class fake as real: 0.5900743007659912
# end of cycle 69
#
#
# Epoch  0/20, Cost: 0.01653045415878296, Probability class real as real: 0.49672001600265503
# Epoch  5/20, Cost: 0.006636977195739746, Probability class real as real: 0.3121965527534485
# Epoch  10/20, Cost: -0.00896616280078888, Probability class real as real: 0.3748125582933426
# Epoch  15/20, Cost: -0.020237818360328674, Probability class real as real: 0.5653424263000488
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145313769578934, Probability class fake as real: 0.7145313769578934
# end of cycle 70
#
#
# Epoch  0/20, Cost: 0.08231959491968155, Probability class real as real: 0.7128046154975891
# Epoch  5/20, Cost: 0.0017883777618408203, Probability class real as real: 0.9006233923137188
# Epoch  10/20, Cost: -0.06869946420192719, Probability class real as real: 0.8325158879160881
# Epoch  15/20, Cost: -0.09306535124778748, Probability class real as real: 0.6465680450201035
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900751501321793, Probability class fake as real: 0.5900751501321793
# end of cycle 71
#
#
# Epoch  0/20, Cost: 0.016530513763427734, Probability class real as real: 0.4967212975025177
# Epoch  5/20, Cost: 0.006637260317802429, Probability class real as real: 0.31219641864299774
# Epoch  10/20, Cost: -0.008965596556663513, Probability class real as real: 0.3748099058866501
# Epoch  15/20, Cost: -0.020237460732460022, Probability class real as real: 0.5653402656316757
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145316153764725, Probability class fake as real: 0.7145316153764725
# end of cycle 72
#
#
# Epoch  0/20, Cost: 0.08231987059116364, Probability class real as real: 0.7128045856952667
# Epoch  5/20, Cost: 0.0017884708940982819, Probability class real as real: 0.9006232395768166
# Epoch  10/20, Cost: -0.06869957596063614, Probability class real as real: 0.832515686750412
# Epoch  15/20, Cost: -0.09306518733501434, Probability class real as real: 0.6465678364038467
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900754481554031, Probability class fake as real: 0.5900754481554031
# end of cycle 73
#
#
# Epoch  0/20, Cost: 0.016530513763427734, Probability class real as real: 0.4967215806245804
# Epoch  5/20, Cost: 0.006637543439865112, Probability class real as real: 0.31219689548015594
# Epoch  10/20, Cost: -0.008965343236923218, Probability class real as real: 0.3748108297586441
# Epoch  15/20, Cost: -0.02023722231388092, Probability class real as real: 0.5653415769338608
# discriminator trained
# Epoch  0/1.0, Cost: -0.714532271027565, Probability class fake as real: 0.714532271027565
# end of cycle 74
#
#
# Epoch  0/20, Cost: 0.0823201909661293, Probability class real as real: 0.7128049582242966
# Epoch  5/20, Cost: 0.0017886795103549957, Probability class real as real: 0.9006237499415874
# Epoch  10/20, Cost: -0.06869953125715256, Probability class real as real: 0.8325164094567299
# Epoch  15/20, Cost: -0.0930653065443039, Probability class real as real: 0.6465684771537781
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900761038064957, Probability class fake as real: 0.5900761038064957
# end of cycle 75
#
#
# Epoch  0/20, Cost: 0.016530603170394897, Probability class real as real: 0.4967225193977356
# Epoch  5/20, Cost: 0.006637692451477051, Probability class real as real: 0.31219707429409027
# Epoch  10/20, Cost: -0.008964762091636658, Probability class real as real: 0.37480971217155457
# Epoch  15/20, Cost: -0.0202367901802063, Probability class real as real: 0.5653409659862518
# discriminator trained
# Epoch  0/1.0, Cost: -0.714532881975174, Probability class fake as real: 0.714532881975174
# end of cycle 76
#
#
# Epoch  0/20, Cost: 0.0823204442858696, Probability class real as real: 0.7128053903579712
# Epoch  5/20, Cost: 0.0017888061702251434, Probability class real as real: 0.9006238952279091
# Epoch  10/20, Cost: -0.06869956105947495, Probability class real as real: 0.8325162306427956
# Epoch  15/20, Cost: -0.09306532144546509, Probability class real as real: 0.6465684473514557
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900765508413315, Probability class fake as real: 0.5900765508413315
# end of cycle 77
#
#
# Epoch  0/20, Cost: 0.016530826687812805, Probability class real as real: 0.496722936630249
# Epoch  5/20, Cost: 0.006638094782829285, Probability class real as real: 0.3121962249279022
# Epoch  10/20, Cost: -0.008964434266090393, Probability class real as real: 0.3748071491718292
# Epoch  15/20, Cost: -0.020236417651176453, Probability class real as real: 0.565338671207428
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145330011844635, Probability class fake as real: 0.7145330011844635
# end of cycle 78
#
#
# Epoch  0/20, Cost: 0.08232076466083527, Probability class real as real: 0.7128051370382309
# Epoch  5/20, Cost: 0.0017891675233840942, Probability class real as real: 0.9006241373717785
# Epoch  10/20, Cost: -0.06869933754205704, Probability class real as real: 0.8325169757008553
# Epoch  15/20, Cost: -0.09306535124778748, Probability class real as real: 0.6465692818164825
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900772362947464, Probability class fake as real: 0.5900772362947464
# end of cycle 79
#
#
# Epoch  0/20, Cost: 0.016530901193618774, Probability class real as real: 0.4967237412929535
# Epoch  5/20, Cost: 0.0066383033990859985, Probability class real as real: 0.3121963292360306
# Epoch  10/20, Cost: -0.008963987231254578, Probability class real as real: 0.3748062998056412
# Epoch  15/20, Cost: -0.020236045122146606, Probability class real as real: 0.5653382241725922
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145339250564575, Probability class fake as real: 0.7145339250564575
# end of cycle 80
#
#
# Epoch  0/20, Cost: 0.08232113718986511, Probability class real as real: 0.7128056585788727
# Epoch  5/20, Cost: 0.001789294183254242, Probability class real as real: 0.9006244726479053
# Epoch  10/20, Cost: -0.06869939714670181, Probability class real as real: 0.8325171247124672
# Epoch  15/20, Cost: -0.09306544065475464, Probability class real as real: 0.6465694159269333
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900778025388718, Probability class fake as real: 0.5900778025388718
# end of cycle 81
#
#
# Epoch  0/20, Cost: 0.016531020402908325, Probability class real as real: 0.49672430753707886
# Epoch  5/20, Cost: 0.006638556718826294, Probability class real as real: 0.31219635903835297
# Epoch  10/20, Cost: -0.008963614702224731, Probability class real as real: 0.3748050779104233
# Epoch  15/20, Cost: -0.020235583186149597, Probability class real as real: 0.5653372555971146
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145346254110336, Probability class fake as real: 0.7145346254110336
# end of cycle 82
#
#
# Epoch  0/20, Cost: 0.08232142776250839, Probability class real as real: 0.7128061801195145
# Epoch  5/20, Cost: 0.0017894245684146881, Probability class real as real: 0.9006249979138374
# Epoch  10/20, Cost: -0.06869915127754211, Probability class real as real: 0.8325173333287239
# Epoch  15/20, Cost: -0.09306536614894867, Probability class real as real: 0.6465697437524796
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900783240795135, Probability class fake as real: 0.5900783240795135
# end of cycle 83
#
#
# Epoch  0/20, Cost: 0.01653110980987549, Probability class real as real: 0.49672508239746094
# Epoch  5/20, Cost: 0.006638914346694946, Probability class real as real: 0.31219616532325745
# Epoch  10/20, Cost: -0.00896318256855011, Probability class real as real: 0.3748038113117218
# Epoch  15/20, Cost: -0.02023535966873169, Probability class real as real: 0.5653357207775116
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145330905914307, Probability class fake as real: 0.7145330905914307
# end of cycle 84
#
#
# Epoch  0/20, Cost: 0.08232207596302032, Probability class real as real: 0.7128040343523026
# Epoch  5/20, Cost: 0.0017901323735713959, Probability class real as real: 0.9006237611174583
# Epoch  10/20, Cost: -0.06869901716709137, Probability class real as real: 0.8325173929333687
# Epoch  15/20, Cost: -0.09306521713733673, Probability class real as real: 0.6465698331594467
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900783836841583, Probability class fake as real: 0.5900783836841583
# end of cycle 85
#
#
# Epoch  0/20, Cost: 0.01653115451335907, Probability class real as real: 0.49672481417655945
# Epoch  5/20, Cost: 0.006639063358306885, Probability class real as real: 0.3121957629919052
# Epoch  10/20, Cost: -0.00896298885345459, Probability class real as real: 0.37480324506759644
# Epoch  15/20, Cost: -0.02023497223854065, Probability class real as real: 0.5653351694345474
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145332843065262, Probability class fake as real: 0.7145332843065262
# end of cycle 86
#
#
# Epoch  0/20, Cost: 0.08232226967811584, Probability class real as real: 0.7128041237592697
# Epoch  5/20, Cost: 0.001790270209312439, Probability class real as real: 0.9006242156028748
# Epoch  10/20, Cost: -0.06869879364967346, Probability class real as real: 0.832518108189106
# Epoch  15/20, Cost: -0.0930652767419815, Probability class real as real: 0.6465706527233124
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900791734457016, Probability class fake as real: 0.5900791734457016
# end of cycle 87
#
#
# Epoch  0/20, Cost: 0.016531243920326233, Probability class real as real: 0.49672573804855347
# Epoch  5/20, Cost: 0.006639331579208374, Probability class real as real: 0.3121948838233948
# Epoch  10/20, Cost: -0.008962348103523254, Probability class real as real: 0.37479938566684723
# Epoch  15/20, Cost: -0.02023455500602722, Probability class real as real: 0.5653326958417892
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145348191261292, Probability class fake as real: 0.7145348191261292
# end of cycle 88
#
#
# Epoch  0/20, Cost: 0.0823226124048233, Probability class real as real: 0.7128053903579712
# Epoch  5/20, Cost: 0.0017903372645378113, Probability class real as real: 0.9006251320242882
# Epoch  10/20, Cost: -0.06869900226593018, Probability class real as real: 0.832518607378006
# Epoch  15/20, Cost: -0.0930653065443039, Probability class real as real: 0.6465710997581482
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900801420211792, Probability class fake as real: 0.5900801420211792
# end of cycle 89
#
#
# Epoch  0/20, Cost: 0.016531482338905334, Probability class real as real: 0.49672697484493256
# Epoch  5/20, Cost: 0.006639629602432251, Probability class real as real: 0.3121957629919052
# Epoch  10/20, Cost: -0.008961975574493408, Probability class real as real: 0.3747997581958771
# Epoch  15/20, Cost: -0.02023431658744812, Probability class real as real: 0.5653334110975266
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145345956087112, Probability class fake as real: 0.7145345956087112
# end of cycle 90
#
#
# Epoch  0/20, Cost: 0.08232284337282181, Probability class real as real: 0.7128047347068787
# Epoch  5/20, Cost: 0.0017907097935676575, Probability class real as real: 0.9006246067583561
# Epoch  10/20, Cost: -0.06869882345199585, Probability class real as real: 0.8325183466076851
# Epoch  15/20, Cost: -0.09306536614894867, Probability class real as real: 0.6465710699558258
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900801420211792, Probability class fake as real: 0.5900801420211792
# end of cycle 91
#
#
# Epoch  0/20, Cost: 0.01653154194355011, Probability class real as real: 0.4967269003391266
# Epoch  5/20, Cost: 0.006639942526817322, Probability class real as real: 0.31219522655010223
# Epoch  10/20, Cost: -0.008961677551269531, Probability class real as real: 0.3747987002134323
# Epoch  15/20, Cost: -0.020233869552612305, Probability class real as real: 0.5653324276208878
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145354598760605, Probability class fake as real: 0.7145354598760605
# end of cycle 92
#
#
# Epoch  0/20, Cost: 0.08232314884662628, Probability class real as real: 0.712805300951004
# Epoch  5/20, Cost: 0.0017909146845340729, Probability class real as real: 0.9006252363324165
# Epoch  10/20, Cost: -0.06869873404502869, Probability class real as real: 0.8325190618634224
# Epoch  15/20, Cost: -0.0930652767419815, Probability class real as real: 0.6465717405080795
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900812149047852, Probability class fake as real: 0.5900812149047852
# end of cycle 93
#
#
# Epoch  0/20, Cost: 0.016531676054000854, Probability class real as real: 0.4967280328273773
# Epoch  5/20, Cost: 0.006640255451202393, Probability class real as real: 0.3121943473815918
# Epoch  10/20, Cost: -0.008961260318756104, Probability class real as real: 0.37479494512081146
# Epoch  15/20, Cost: -0.02023361623287201, Probability class real as real: 0.5653296411037445
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145354896783829, Probability class fake as real: 0.7145354896783829
# end of cycle 94
#
#
# Epoch  0/20, Cost: 0.08232352137565613, Probability class real as real: 0.7128051370382309
# Epoch  5/20, Cost: 0.001791093498468399, Probability class real as real: 0.9006253182888031
# Epoch  10/20, Cost: -0.0686987116932869, Probability class real as real: 0.8325192183256149
# Epoch  15/20, Cost: -0.09306542575359344, Probability class real as real: 0.646572008728981
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900815427303314, Probability class fake as real: 0.5900815427303314
# end of cycle 95
#
#
# Epoch  0/20, Cost: 0.01653185486793518, Probability class real as real: 0.49672847986221313
# Epoch  5/20, Cost: 0.006640419363975525, Probability class real as real: 0.312195286154747
# Epoch  10/20, Cost: -0.0089607834815979, Probability class real as real: 0.37479615211486816
# Epoch  15/20, Cost: -0.020233213901519775, Probability class real as real: 0.5653297901153564
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145348191261292, Probability class fake as real: 0.7145348191261292
# end of cycle 96
#
#
# Epoch  0/20, Cost: 0.08232386410236359, Probability class real as real: 0.7128040939569473
# Epoch  5/20, Cost: 0.0017914995551109314, Probability class real as real: 0.9006248451769352
# Epoch  10/20, Cost: -0.06869854778051376, Probability class real as real: 0.8325195536017418
# Epoch  15/20, Cost: -0.0930653065443039, Probability class real as real: 0.6465722918510437
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900817364454269, Probability class fake as real: 0.5900817364454269
# end of cycle 97
#
#
# Epoch  0/20, Cost: 0.01653188467025757, Probability class real as real: 0.49672867357730865
# Epoch  5/20, Cost: 0.006640732288360596, Probability class real as real: 0.31219516694545746
# Epoch  10/20, Cost: -0.008960634469985962, Probability class real as real: 0.3747958093881607
# Epoch  15/20, Cost: -0.020232707262039185, Probability class real as real: 0.5653297454118729
# discriminator trained
# Epoch  0/1.0, Cost: -0.7145359963178635, Probability class fake as real: 0.7145359963178635
# end of cycle 98
#
#
# Epoch  0/20, Cost: 0.08232404291629791, Probability class real as real: 0.7128050178289413
# Epoch  5/20, Cost: 0.0017916113138198853, Probability class real as real: 0.9006256125867367
# Epoch  10/20, Cost: -0.06869864463806152, Probability class real as real: 0.8325202763080597
# Epoch  15/20, Cost: -0.09306532144546509, Probability class real as real: 0.6465730369091034
# discriminator trained
# Epoch  0/1.0, Cost: -0.5900827795267105, Probability class fake as real: 0.5900827795267105
# end of cycle 99

# %% [markdown]
# Bloch representation & difference in the vectors

# %%
obs = [qml.PauliX(0), qml.PauliY(0), qml.PauliZ(0)]

bloch_vector_real = qml.map(real, obs, dev, interface="torch")
bloch_vector_generator = qml.map(generator, obs, dev, interface="torch")

bloch_real = bloch_vector_real([phi, theta, omega]).detach().numpy()
bloch_generated = bloch_vector_generator(gen_weights_grad).detach().numpy()
difference = np.absolute(bloch_real - bloch_generated)

print("Real Bloch vector: {}".format(bloch_real))
print("Generator Bloch vector: {}".format(bloch_generated))
print("Difference: {}".format(difference))
# Out:
# Real Bloch vector: [0.90096882 0.43388376 0.        ]
# Generator Bloch vector: [ 0.91672719  0.39813149 -0.03320512]
# Difference: [0.01575837 0.03575227 0.03320512]
