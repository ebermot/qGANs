# %%
# This cell is added by sphinx-gallery
# It can be customized to whatever you like
# %matplotlib inline

# %%
import pennylane as qml
from pennylane import numpy as np
import tensorflow as tf
import qutip as qt
from matplotlib import pyplot as plt

# %% [markdown]
# We also declare a 3-qubit simulator device running in Cirq.

# %%
dev = qml.device('cirq.simulator', wires=2)

# %% [markdown]
# Generator and Discriminator
# ===========================

# %%
#For now I remove the CNOT because that is to generate arbitrary mixed states, and now I go for pure states.

def generator(w):
    #qml.Hadamard(wires=0)
    #qml.RY(w[0],wires = 0)
    #qml.CNOT(wires = [0,1])
    #qml.RX(w[1],wires = 0)
    #qml.RZ(w[2],wires = 0)
    
    qml.RZ(w[0], wires=0)
    qml.RY(w[1], wires=0)
    qml.RZ(w[2], wires=0)
    

def U1(w,wire):
    qml.RZ(w[0],wires = wire)
    qml.RX(w[1],wires = wire)
    qml.RZ(w[2],wires = wire)    
    
def discriminator(w):
    #qml.Hadamard(wires=0)
    #qml.CNOT(wires = [1,0])
    #qml.RY(w[0],wires = 1)
    #qml.CNOT(wires = [0,1])
    #qml.RY(w[1],wires = 1)
    #qml.CNOT(wires = [1,0])
    #qml.RZ(w[2],wires = 0)
    #qml.RX(w[3],wires = 0)
    
    #qml.Hadamard(wires=0)
    #qml.RX(w[0], wires=0)
    #qml.RX(w[1], wires=2)
    #qml.RY(w[2], wires=0)
    #qml.RY(w[3], wires=2)
    #qml.RZ(w[4], wires=0)
    #qml.RZ(w[5], wires=2)
    #qml.CNOT(wires=[0, 2])
    #qml.RX(w[6], wires=2)
    #qml.RY(w[7], wires=2)
    #qml.RZ(w[8], wires=2)
    U1(w[0:3], 0)
    U1(w[3:6], 1)
    qml.CNOT(wires = [1,0])
    qml.RZ(w[6],wires = 0)
    qml.RY(w[7],wires = 1)
    qml.CNOT(wires = [0,1])
    qml.RY(w[8],wires = 1)
    qml.CNOT(wires = [1,0])
    U1(w[9:12], 0)
    U1(w[12:15],1)
    
def real(w):
    generator(w)

# %% [markdown]
# # Nodes

# %%
@qml.qnode(dev, diff_method="parameter-shift")
def real_disc_circuit(real_params, disc_weights):
    real(real_params)
    discriminator(disc_weights)
    return qml.expval(qml.PauliZ(1))

@qml.qnode(dev, diff_method="parameter-shift")
def gen_disc_circuit(gen_weights, disc_weights):
    generator(gen_weights)
    discriminator(disc_weights)
    return qml.expval(qml.PauliZ(1))

# %% [markdown]
# QGAN cost functions
# ===================

# %%
def prob_real_true(disc_weights):
    true_disc_output = real_disc_circuit(real_params, disc_weights)
    # convert to probability
    prob_real_true = (true_disc_output + 1) / 2
    return prob_real_true


def prob_fake_true(gen_weights, disc_weights):
    fake_disc_output = gen_disc_circuit(gen_weights, disc_weights)
    # convert to probability
    prob_fake_true = (fake_disc_output + 1) / 2
    return prob_fake_true


def disc_cost(disc_weights):
    cost = prob_fake_true(gen_weights, disc_weights) - prob_real_true(disc_weights)
    return cost


def gen_cost(gen_weights):
    cost = -prob_fake_true(gen_weights, disc_weights)
    return cost

# %% [markdown]
# Initializing the weights
# =================

# %% [markdown]
# Real state generation

# %%
np.random.seed(0)
real_params = np.random.uniform(low=-np.pi, high=np.pi, size=3)

# %% [markdown]
# Generator and Discriminator parameter initialization

# %%
np.random.seed(17)
init_gen_weights = np.random.uniform(low=-np.pi, high=np.pi, size=3)
np.random.seed(17)
init_disc_weights = np.random.uniform(low=-np.pi, high=np.pi, size=15)

gen_weights=np.array(list(init_gen_weights), requires_grad=False)

disc_weights=np.array(list(init_disc_weights), requires_grad=True)

# %% [markdown]
# We begin by creating the optimizer:

# %%
opt1=qml.GradientDescentOptimizer(stepsize=0.05)
opt2=qml.GradientDescentOptimizer(stepsize=0.05)

# %% [markdown]
# We train in turns. We expect around 250 turns to converge. Each turn consists of 5 discriminator steps and 1 generator step.

# %% [markdown]
# # Define some other metrics

# %%
dev_state = qml.device('default.qubit', wires=1)

# %%
@qml.qnode(dev_state, interface="tf")
def real_circuit(w):
    generator(w)
    return qml.state()


@qml.qnode(dev_state, interface="tf")
def gen_circuit(gen_weights):
    generator(gen_weights)
    return qml.state()

# %%
def F_Tr_state(real_params,gen_weights):
    real_state = qt.Qobj(real_circuit(real_params).numpy())
    gen_state = qt.Qobj(gen_circuit(gen_weights).numpy())
    
    ρ_R = real_state * real_state.dag()
    ρ_G = gen_state * gen_state.dag()
    
    F = qt.fidelity(ρ_R,ρ_G)
    d = qt.tracedist(ρ_R,ρ_G)
    
    return (F,d,real_state,gen_state)

# %% [markdown]
# # Training routine

# %%
#----- Metrics ----------------------------

Disc_cost = [] # P(R|R)-P(R|G)
Gen_cost = [] # P(R|G)
Trace_d = [] #Trace distance
F = [] #Fidelity
States = []


#-------------------------------------------

costD = lambda: disc_cost(disc_weights)
costG = lambda: gen_cost(gen_weights)

#print("gen_weights", gen_weights)
#print("disc_weights", disc_weights)

for turn in range(100):
    print("Begin "+ str(turn) + " discriminator optimization")
    disc_weights=np.array(list(disc_weights), requires_grad=True)
    gen_weights=np.array(list(gen_weights), requires_grad=False)
    for step in range(5): #The actual ratio should be 20 to 1, according to what we discussed
        #opt.minimize(costD, disc_weights)
        print("Before "+str(step) + " disc gradient computation of "+str(turn)+ " round of optimization")
        #grad_fn_disc=real_disc_circuit_gradient(disc_weights)-gen_disc_circuit_gradient_disc(disc_weights)
        grad_gen_circuit_disc=qml.grad(gen_disc_circuit, argnum=1)
        grad_real_disc_circuit=qml.grad(real_disc_circuit, argnum=1) 
        grad_fn_disc=grad_gen_circuit_disc(gen_weights, disc_weights)-grad_real_disc_circuit(real_params, disc_weights)
        #print("grad_fn_disc", grad_fn_disc)
        print("After"+str(step) + " disc gradient computation of "+str(turn)+ " round of optimization")
        disc_weights=np.array(opt1.apply_grad(grad_fn_disc, disc_weights), requires_grad=True)
        #disc_weights=np.array(opt1.step(disc_cost, disc_weights), requires_grad=True)
        #print("disc_weights", disc_weights)
        print("After"+str(step) + " disc opt update of "+str(turn)+ " round of optimization")

        if step == 4:
            costD_val = costD().numpy()
            print("Step {}: cost = {}".format(step, costD_val))
            Disc_cost += [-costD_val] # P(R|R)-P(R|G)
    print("End of " + str(turn)+" discriminator optimization")    
    print("end of "+ str(turn)+ " optimization ")
            #opt.minimize(costG, gen_weights)
    disc_weights=np.array(list(disc_weights), requires_grad=False)
    gen_weights=np.array(list(gen_weights), requires_grad=True)
    print("Begin of "+str(turn)+" generator optimization")
    #print("gen_weights", gen_weights)
    #print("disc_weights", disc_weights)
    #disc_weights=np.array(list(disc_weights), requires_grad=False)
    #gen_weights=np.array(list(gen_weights), requires_grad=True)

    print("Before gen gradient computation")
    #grad_fn_gen=-gen_disc_circuit_gradient_gen(gen_weights)
    grad_fn_gen=-qml.grad(gen_disc_circuit, argnum=0)(gen_weights, disc_weights)
    #print("grad_fn_gen", grad_fn_gen)
    print("After gen gradient computation")
    gen_weights=np.array(opt2.apply_grad(grad_fn_gen, gen_weights), requires_grad=True)
    #gen_weights=np.array(opt2.step(gen_cost, gen_weights), requires_grad=True)
    #print("gen_weights", gen_weights)
    #print("disc_weights", disc_weights)
    print("After gen opt update ")
    costG_val = costG().numpy()
    #print("Step {}: cost = {}".format(step, costG_val))
    Gen_cost += [-costG_val] # P(R|G)
    
 

    F_Tr_st = F_Tr_state(real_params,gen_weights)
    
    
    F += [F_Tr_st[0]] #Fidelity
    Trace_d += [F_Tr_st[1]] #Trace distance
    States += [F_Tr_st[3]]
    
    print("P(R|R)-P(R|G): ", -costD_val)
    print("P(R|G): ", -costG_val)
    print("Fidelity: ",F_Tr_st[0])
    print("Trace distance: ",F_Tr_st[1])
    print("------------------------------")
# Out:
# Begin 0 discriminator optimization
# Before 0 disc gradient computation of 0 round of optimization
# After0 disc gradient computation of 0 round of optimization
# After0 disc opt update of 0 round of optimization
# Before 1 disc gradient computation of 0 round of optimization
# After1 disc gradient computation of 0 round of optimization
# After1 disc opt update of 0 round of optimization
# Before 2 disc gradient computation of 0 round of optimization
# After2 disc gradient computation of 0 round of optimization
# After2 disc opt update of 0 round of optimization
# Before 3 disc gradient computation of 0 round of optimization
# After3 disc gradient computation of 0 round of optimization
# After3 disc opt update of 0 round of optimization
# Before 4 disc gradient computation of 0 round of optimization
# After4 disc gradient computation of 0 round of optimization
# After4 disc opt update of 0 round of optimization
# Step 4: cost = -0.3766554109752178
# End of 0 discriminator optimization
# end of 0 optimization
# Begin of 0 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.3766554109752178
# P(R|G):  0.5743272453546524
# Fidelity:  0.7374004178938406
# Trace distance:  0.6754558636135964
# ------------------------------
# Begin 1 discriminator optimization
# Before 0 disc gradient computation of 1 round of optimization
# After0 disc gradient computation of 1 round of optimization
# After0 disc opt update of 1 round of optimization
# Before 1 disc gradient computation of 1 round of optimization
# After1 disc gradient computation of 1 round of optimization
# After1 disc opt update of 1 round of optimization
# Before 2 disc gradient computation of 1 round of optimization
# After2 disc gradient computation of 1 round of optimization
# After2 disc opt update of 1 round of optimization
# Before 3 disc gradient computation of 1 round of optimization
# After3 disc gradient computation of 1 round of optimization
# After3 disc opt update of 1 round of optimization
# Before 4 disc gradient computation of 1 round of optimization
# After4 disc gradient computation of 1 round of optimization
# After4 disc opt update of 1 round of optimization
# Step 4: cost = -0.5127645172178745
# End of 1 discriminator optimization
# end of 1 optimization
# Begin of 1 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.5127645172178745
# P(R|G):  0.43214331567287445
# Fidelity:  0.747971930721231
# Trace distance:  0.663730360050792
# ------------------------------
# Begin 2 discriminator optimization
# Before 0 disc gradient computation of 2 round of optimization
# After0 disc gradient computation of 2 round of optimization
# After0 disc opt update of 2 round of optimization
# Before 1 disc gradient computation of 2 round of optimization
# After1 disc gradient computation of 2 round of optimization
# After1 disc opt update of 2 round of optimization
# Before 2 disc gradient computation of 2 round of optimization
# After2 disc gradient computation of 2 round of optimization
# After2 disc opt update of 2 round of optimization
# Before 3 disc gradient computation of 2 round of optimization
# After3 disc gradient computation of 2 round of optimization
# After3 disc opt update of 2 round of optimization
# Before 4 disc gradient computation of 2 round of optimization
# After4 disc gradient computation of 2 round of optimization
# After4 disc opt update of 2 round of optimization
# Step 4: cost = -0.5805075280368328
# End of 2 discriminator optimization
# end of 2 optimization
# Begin of 2 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.5805075280368328
# P(R|G):  0.333740234375
# Fidelity:  0.757857581662598
# Trace distance:  0.652420022620795
# ------------------------------
# Begin 3 discriminator optimization
# Before 0 disc gradient computation of 3 round of optimization
# After0 disc gradient computation of 3 round of optimization
# After0 disc opt update of 3 round of optimization
# Before 1 disc gradient computation of 3 round of optimization
# After1 disc gradient computation of 3 round of optimization
# After1 disc opt update of 3 round of optimization
# Before 2 disc gradient computation of 3 round of optimization
# After2 disc gradient computation of 3 round of optimization
# After2 disc opt update of 3 round of optimization
# Before 3 disc gradient computation of 3 round of optimization
# After3 disc gradient computation of 3 round of optimization
# After3 disc opt update of 3 round of optimization
# Before 4 disc gradient computation of 3 round of optimization
# After4 disc gradient computation of 3 round of optimization
# After4 disc opt update of 3 round of optimization
# Step 4: cost = -0.6092034950852394
# End of 3 discriminator optimization
# end of 3 optimization
# Begin of 3 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.6092034950852394
# P(R|G):  0.27505773305892944
# Fidelity:  0.767233120704273
# Trace distance:  0.6413683329369971
# ------------------------------
# Begin 4 discriminator optimization
# Before 0 disc gradient computation of 4 round of optimization
# After0 disc gradient computation of 4 round of optimization
# After0 disc opt update of 4 round of optimization
# Before 1 disc gradient computation of 4 round of optimization
# After1 disc gradient computation of 4 round of optimization
# After1 disc opt update of 4 round of optimization
# Before 2 disc gradient computation of 4 round of optimization
# After2 disc gradient computation of 4 round of optimization
# After2 disc opt update of 4 round of optimization
# Before 3 disc gradient computation of 4 round of optimization
# After3 disc gradient computation of 4 round of optimization
# After3 disc opt update of 4 round of optimization
# Before 4 disc gradient computation of 4 round of optimization
# After4 disc gradient computation of 4 round of optimization
# After4 disc opt update of 4 round of optimization
# Step 4: cost = -0.6181335002183914
# End of 4 discriminator optimization
# end of 4 optimization
# Begin of 4 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.6181335002183914
# P(R|G):  0.24327005445957184
# Fidelity:  0.776270942746032
# Trace distance:  0.6303994239049965
# ------------------------------
# Begin 5 discriminator optimization
# Before 0 disc gradient computation of 5 round of optimization
# After0 disc gradient computation of 5 round of optimization
# After0 disc opt update of 5 round of optimization
# Before 1 disc gradient computation of 5 round of optimization
# After1 disc gradient computation of 5 round of optimization
# After1 disc opt update of 5 round of optimization
# Before 2 disc gradient computation of 5 round of optimization
# After2 disc gradient computation of 5 round of optimization
# After2 disc opt update of 5 round of optimization
# Before 3 disc gradient computation of 5 round of optimization
# After3 disc gradient computation of 5 round of optimization
# After3 disc opt update of 5 round of optimization
# Before 4 disc gradient computation of 5 round of optimization
# After4 disc gradient computation of 5 round of optimization
# After4 disc opt update of 5 round of optimization
# Step 4: cost = -0.6173697784543037
# End of 5 discriminator optimization
# end of 5 optimization
# Begin of 5 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.6173697784543037
# P(R|G):  0.2277747243642807
# Fidelity:  0.7850889764947573
# Trace distance:  0.6193829986255797
# ------------------------------
# Begin 6 discriminator optimization
# Before 0 disc gradient computation of 6 round of optimization
# After0 disc gradient computation of 6 round of optimization
# After0 disc opt update of 6 round of optimization
# Before 1 disc gradient computation of 6 round of optimization
# After1 disc gradient computation of 6 round of optimization
# After1 disc opt update of 6 round of optimization
# Before 2 disc gradient computation of 6 round of optimization
# After2 disc gradient computation of 6 round of optimization
# After2 disc opt update of 6 round of optimization
# Before 3 disc gradient computation of 6 round of optimization
# After3 disc gradient computation of 6 round of optimization
# After3 disc opt update of 6 round of optimization
# Before 4 disc gradient computation of 6 round of optimization
# After4 disc gradient computation of 6 round of optimization
# After4 disc opt update of 6 round of optimization
# Step 4: cost = -0.6117513254284859
# End of 6 discriminator optimization
# end of 6 optimization
# Begin of 6 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.6117513254284859
# P(R|G):  0.22179444879293442
# Fidelity:  0.7937583937113645
# Trace distance:  0.6082331936177403
# ------------------------------
# Begin 7 discriminator optimization
# Before 0 disc gradient computation of 7 round of optimization
# After0 disc gradient computation of 7 round of optimization
# After0 disc opt update of 7 round of optimization
# Before 1 disc gradient computation of 7 round of optimization
# After1 disc gradient computation of 7 round of optimization
# After1 disc opt update of 7 round of optimization
# Before 2 disc gradient computation of 7 round of optimization
# After2 disc gradient computation of 7 round of optimization
# After2 disc opt update of 7 round of optimization
# Before 3 disc gradient computation of 7 round of optimization
# After3 disc gradient computation of 7 round of optimization
# After3 disc opt update of 7 round of optimization
# Before 4 disc gradient computation of 7 round of optimization
# After4 disc gradient computation of 7 round of optimization
# After4 disc opt update of 7 round of optimization
# Step 4: cost = -0.603568397462368
# End of 7 discriminator optimization
# end of 7 optimization
# Begin of 7 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.603568397462368
# P(R|G):  0.2213539183139801
# Fidelity:  0.802319386765505
# Trace distance:  0.5968949669918691
# ------------------------------
# Begin 8 discriminator optimization
# Before 0 disc gradient computation of 8 round of optimization
# After0 disc gradient computation of 8 round of optimization
# After0 disc opt update of 8 round of optimization
# Before 1 disc gradient computation of 8 round of optimization
# After1 disc gradient computation of 8 round of optimization
# After1 disc opt update of 8 round of optimization
# Before 2 disc gradient computation of 8 round of optimization
# After2 disc gradient computation of 8 round of optimization
# After2 disc opt update of 8 round of optimization
# Before 3 disc gradient computation of 8 round of optimization
# After3 disc gradient computation of 8 round of optimization
# After3 disc opt update of 8 round of optimization
# Before 4 disc gradient computation of 8 round of optimization
# After4 disc gradient computation of 8 round of optimization
# After4 disc opt update of 8 round of optimization
# Step 4: cost = -0.5939216464757919
# End of 8 discriminator optimization
# end of 8 optimization
# Begin of 8 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.5939216464757919
# P(R|G):  0.22418390214443207
# Fidelity:  0.8107936384320232
# Trace distance:  0.5853321160688119
# ------------------------------
# Begin 9 discriminator optimization
# Before 0 disc gradient computation of 9 round of optimization
# After0 disc gradient computation of 9 round of optimization
# After0 disc opt update of 9 round of optimization
# Before 1 disc gradient computation of 9 round of optimization
# After1 disc gradient computation of 9 round of optimization
# After1 disc opt update of 9 round of optimization
# Before 2 disc gradient computation of 9 round of optimization
# After2 disc gradient computation of 9 round of optimization
# After2 disc opt update of 9 round of optimization
# Before 3 disc gradient computation of 9 round of optimization
# After3 disc gradient computation of 9 round of optimization
# After3 disc opt update of 9 round of optimization
# Before 4 disc gradient computation of 9 round of optimization
# After4 disc gradient computation of 9 round of optimization
# After4 disc opt update of 9 round of optimization
# Step 4: cost = -0.5833529159426689
# End of 9 discriminator optimization
# end of 9 optimization
# Begin of 9 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.5833529159426689
# P(R|G):  0.22899281233549118
# Fidelity:  0.8191922261228228
# Trace distance:  0.5735190464665791
# ------------------------------
# Begin 10 discriminator optimization
# Before 0 disc gradient computation of 10 round of optimization
# After0 disc gradient computation of 10 round of optimization
# After0 disc opt update of 10 round of optimization
# Before 1 disc gradient computation of 10 round of optimization
# After1 disc gradient computation of 10 round of optimization
# After1 disc opt update of 10 round of optimization
# Before 2 disc gradient computation of 10 round of optimization
# After2 disc gradient computation of 10 round of optimization
# After2 disc opt update of 10 round of optimization
# Before 3 disc gradient computation of 10 round of optimization
# After3 disc gradient computation of 10 round of optimization
# After3 disc opt update of 10 round of optimization
# Before 4 disc gradient computation of 10 round of optimization
# After4 disc gradient computation of 10 round of optimization
# After4 disc opt update of 10 round of optimization
# Step 4: cost = -0.5721354633569717
# End of 10 discriminator optimization
# end of 10 optimization
# Begin of 10 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.5721354633569717
# P(R|G):  0.23504386842250824
# Fidelity:  0.8275203856171528
# Trace distance:  0.561435679004175
# ------------------------------
# Begin 11 discriminator optimization
# Before 0 disc gradient computation of 11 round of optimization
# After0 disc gradient computation of 11 round of optimization
# After0 disc opt update of 11 round of optimization
# Before 1 disc gradient computation of 11 round of optimization
# After1 disc gradient computation of 11 round of optimization
# After1 disc opt update of 11 round of optimization
# Before 2 disc gradient computation of 11 round of optimization
# After2 disc gradient computation of 11 round of optimization
# After2 disc opt update of 11 round of optimization
# Before 3 disc gradient computation of 11 round of optimization
# After3 disc gradient computation of 11 round of optimization
# After3 disc opt update of 11 round of optimization
# Before 4 disc gradient computation of 11 round of optimization
# After4 disc gradient computation of 11 round of optimization
# After4 disc opt update of 11 round of optimization
# Step 4: cost = -0.5604111477732658
# End of 11 discriminator optimization
# end of 11 optimization
# Begin of 11 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.5604111477732658
# P(R|G):  0.24191348254680634
# Fidelity:  0.8357800395363149
# Trace distance:  0.5490644092569436
# ------------------------------
# Begin 12 discriminator optimization
# Before 0 disc gradient computation of 12 round of optimization
# After0 disc gradient computation of 12 round of optimization
# After0 disc opt update of 12 round of optimization
# Before 1 disc gradient computation of 12 round of optimization
# After1 disc gradient computation of 12 round of optimization
# After1 disc opt update of 12 round of optimization
# Before 2 disc gradient computation of 12 round of optimization
# After2 disc gradient computation of 12 round of optimization
# After2 disc opt update of 12 round of optimization
# Before 3 disc gradient computation of 12 round of optimization
# After3 disc gradient computation of 12 round of optimization
# After3 disc opt update of 12 round of optimization
# Before 4 disc gradient computation of 12 round of optimization
# After4 disc gradient computation of 12 round of optimization
# After4 disc opt update of 12 round of optimization
# Step 4: cost = -0.5482508540153503
# End of 12 discriminator optimization
# end of 12 optimization
# Begin of 12 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.5482508540153503
# P(R|G):  0.24935851991176605
# Fidelity:  0.843971252812037
# Trace distance:  0.5363884081772088
# ------------------------------
# Begin 13 discriminator optimization
# Before 0 disc gradient computation of 13 round of optimization
# After0 disc gradient computation of 13 round of optimization
# After0 disc opt update of 13 round of optimization
# Before 1 disc gradient computation of 13 round of optimization
# After1 disc gradient computation of 13 round of optimization
# After1 disc opt update of 13 round of optimization
# Before 2 disc gradient computation of 13 round of optimization
# After2 disc gradient computation of 13 round of optimization
# After2 disc opt update of 13 round of optimization
# Before 3 disc gradient computation of 13 round of optimization
# After3 disc gradient computation of 13 round of optimization
# After3 disc opt update of 13 round of optimization
# Before 4 disc gradient computation of 13 round of optimization
# After4 disc gradient computation of 13 round of optimization
# After4 disc opt update of 13 round of optimization
# Step 4: cost = -0.5356896370649338
# End of 13 discriminator optimization
# end of 13 optimization
# Begin of 13 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.5356896370649338
# P(R|G):  0.2572384774684906
# Fidelity:  0.8520927973506731
# Trace distance:  0.5233907380753934
# ------------------------------
# Begin 14 discriminator optimization
# Before 0 disc gradient computation of 14 round of optimization
# After0 disc gradient computation of 14 round of optimization
# After0 disc opt update of 14 round of optimization
# Before 1 disc gradient computation of 14 round of optimization
# After1 disc gradient computation of 14 round of optimization
# After1 disc opt update of 14 round of optimization
# Before 2 disc gradient computation of 14 round of optimization
# After2 disc gradient computation of 14 round of optimization
# After2 disc opt update of 14 round of optimization
# Before 3 disc gradient computation of 14 round of optimization
# After3 disc gradient computation of 14 round of optimization
# After3 disc opt update of 14 round of optimization
# Before 4 disc gradient computation of 14 round of optimization
# After4 disc gradient computation of 14 round of optimization
# After4 disc opt update of 14 round of optimization
# Step 4: cost = -0.5227410197257996
# End of 14 discriminator optimization
# end of 14 optimization
# Begin of 14 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.5227410197257996
# P(R|G):  0.26547491550445557
# Fidelity:  0.8601424195347325
# Trace distance:  0.5100539518882321
# ------------------------------
# Begin 15 discriminator optimization
# Before 0 disc gradient computation of 15 round of optimization
# After0 disc gradient computation of 15 round of optimization
# After0 disc opt update of 15 round of optimization
# Before 1 disc gradient computation of 15 round of optimization
# After1 disc gradient computation of 15 round of optimization
# After1 disc opt update of 15 round of optimization
# Before 2 disc gradient computation of 15 round of optimization
# After2 disc gradient computation of 15 round of optimization
# After2 disc opt update of 15 round of optimization
# Before 3 disc gradient computation of 15 round of optimization
# After3 disc gradient computation of 15 round of optimization
# After3 disc opt update of 15 round of optimization
# Before 4 disc gradient computation of 15 round of optimization
# After4 disc gradient computation of 15 round of optimization
# After4 disc opt update of 15 round of optimization
# Step 4: cost = -0.5094081461429596
# End of 15 discriminator optimization
# end of 15 optimization
# Begin of 15 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.5094081461429596
# P(R|G):  0.27402377128601074
# Fidelity:  0.8681168101418238
# Trace distance:  0.4963599540144078
# ------------------------------
# Begin 16 discriminator optimization
# Before 0 disc gradient computation of 16 round of optimization
# After0 disc gradient computation of 16 round of optimization
# After0 disc opt update of 16 round of optimization
# Before 1 disc gradient computation of 16 round of optimization
# After1 disc gradient computation of 16 round of optimization
# After1 disc opt update of 16 round of optimization
# Before 2 disc gradient computation of 16 round of optimization
# After2 disc gradient computation of 16 round of optimization
# After2 disc opt update of 16 round of optimization
# Before 3 disc gradient computation of 16 round of optimization
# After3 disc gradient computation of 16 round of optimization
# After3 disc opt update of 16 round of optimization
# Before 4 disc gradient computation of 16 round of optimization
# After4 disc gradient computation of 16 round of optimization
# After4 disc opt update of 16 round of optimization
# Step 4: cost = -0.4956854060292244
# End of 16 discriminator optimization
# end of 16 optimization
# Begin of 16 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.4956854060292244
# P(R|G):  0.28286445140838623
# Fidelity:  0.8760115562813754
# Trace distance:  0.48229012494031753
# ------------------------------
# Begin 17 discriminator optimization
# Before 0 disc gradient computation of 17 round of optimization
# After0 disc gradient computation of 17 round of optimization
# After0 disc opt update of 17 round of optimization
# Before 1 disc gradient computation of 17 round of optimization
# After1 disc gradient computation of 17 round of optimization
# After1 disc opt update of 17 round of optimization
# Before 2 disc gradient computation of 17 round of optimization
# After2 disc gradient computation of 17 round of optimization
# After2 disc opt update of 17 round of optimization
# Before 3 disc gradient computation of 17 round of optimization
# After3 disc gradient computation of 17 round of optimization
# After3 disc opt update of 17 round of optimization
# Before 4 disc gradient computation of 17 round of optimization
# After4 disc gradient computation of 17 round of optimization
# After4 disc opt update of 17 round of optimization
# Step 4: cost = -0.48156359791755676
# End of 17 discriminator optimization
# end of 17 optimization
# Begin of 17 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.48156359791755676
# P(R|G):  0.2919885963201523
# Fidelity:  0.8838208620055406
# Trace distance:  0.46782548443173033
# ------------------------------
# Begin 18 discriminator optimization
# Before 0 disc gradient computation of 18 round of optimization
# After0 disc gradient computation of 18 round of optimization
# After0 disc opt update of 18 round of optimization
# Before 1 disc gradient computation of 18 round of optimization
# After1 disc gradient computation of 18 round of optimization
# After1 disc opt update of 18 round of optimization
# Before 2 disc gradient computation of 18 round of optimization
# After2 disc gradient computation of 18 round of optimization
# After2 disc opt update of 18 round of optimization
# Before 3 disc gradient computation of 18 round of optimization
# After3 disc gradient computation of 18 round of optimization
# After3 disc opt update of 18 round of optimization
# Before 4 disc gradient computation of 18 round of optimization
# After4 disc gradient computation of 18 round of optimization
# After4 disc opt update of 18 round of optimization
# Step 4: cost = -0.46703021973371506
# End of 18 discriminator optimization
# end of 18 optimization
# Begin of 18 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.46703021973371506
# P(R|G):  0.3013968765735626
# Fidelity:  0.8915374548059481
# Trace distance:  0.45294697998566247
# ------------------------------
# Begin 19 discriminator optimization
# Before 0 disc gradient computation of 19 round of optimization
# After0 disc gradient computation of 19 round of optimization
# After0 disc opt update of 19 round of optimization
# Before 1 disc gradient computation of 19 round of optimization
# After1 disc gradient computation of 19 round of optimization
# After1 disc opt update of 19 round of optimization
# Before 2 disc gradient computation of 19 round of optimization
# After2 disc gradient computation of 19 round of optimization
# After2 disc opt update of 19 round of optimization
# Before 3 disc gradient computation of 19 round of optimization
# After3 disc gradient computation of 19 round of optimization
# After3 disc opt update of 19 round of optimization
# Before 4 disc gradient computation of 19 round of optimization
# After4 disc gradient computation of 19 round of optimization
# After4 disc opt update of 19 round of optimization
# Step 4: cost = -0.45207056403160095
# End of 19 discriminator optimization
# end of 19 optimization
# Begin of 19 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.45207056403160095
# P(R|G):  0.3110954761505127
# Fidelity:  0.899152307392063
# Trace distance:  0.4376358396104342
# ------------------------------
# Begin 20 discriminator optimization
# Before 0 disc gradient computation of 20 round of optimization
# After0 disc gradient computation of 20 round of optimization
# After0 disc opt update of 20 round of optimization
# Before 1 disc gradient computation of 20 round of optimization
# After1 disc gradient computation of 20 round of optimization
# After1 disc opt update of 20 round of optimization
# Before 2 disc gradient computation of 20 round of optimization
# After2 disc gradient computation of 20 round of optimization
# After2 disc opt update of 20 round of optimization
# Before 3 disc gradient computation of 20 round of optimization
# After3 disc gradient computation of 20 round of optimization
# After3 disc opt update of 20 round of optimization
# Before 4 disc gradient computation of 20 round of optimization
# After4 disc gradient computation of 20 round of optimization
# After4 disc opt update of 20 round of optimization
# Step 4: cost = -0.43666933476924896
# End of 20 discriminator optimization
# end of 20 optimization
# Begin of 20 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.43666933476924896
# P(R|G):  0.32109422981739044
# Fidelity:  0.9066545144943357
# Trace distance:  0.4218739187503764
# ------------------------------
# Begin 21 discriminator optimization
# Before 0 disc gradient computation of 21 round of optimization
# After0 disc gradient computation of 21 round of optimization
# After0 disc opt update of 21 round of optimization
# Before 1 disc gradient computation of 21 round of optimization
# After1 disc gradient computation of 21 round of optimization
# After1 disc opt update of 21 round of optimization
# Before 2 disc gradient computation of 21 round of optimization
# After2 disc gradient computation of 21 round of optimization
# After2 disc opt update of 21 round of optimization
# Before 3 disc gradient computation of 21 round of optimization
# After3 disc gradient computation of 21 round of optimization
# After3 disc opt update of 21 round of optimization
# Before 4 disc gradient computation of 21 round of optimization
# After4 disc gradient computation of 21 round of optimization
# After4 disc opt update of 21 round of optimization
# Step 4: cost = -0.4208116829395294
# End of 21 discriminator optimization
# end of 21 optimization
# Begin of 21 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.4208116829395294
# P(R|G):  0.3314049690961838
# Fidelity:  0.9140310961695941
# Trace distance:  0.40564413431692337
# ------------------------------
# Begin 22 discriminator optimization
# Before 0 disc gradient computation of 22 round of optimization
# After0 disc gradient computation of 22 round of optimization
# After0 disc opt update of 22 round of optimization
# Before 1 disc gradient computation of 22 round of optimization
# After1 disc gradient computation of 22 round of optimization
# After1 disc opt update of 22 round of optimization
# Before 2 disc gradient computation of 22 round of optimization
# After2 disc gradient computation of 22 round of optimization
# After2 disc opt update of 22 round of optimization
# Before 3 disc gradient computation of 22 round of optimization
# After3 disc gradient computation of 22 round of optimization
# After3 disc opt update of 22 round of optimization
# Before 4 disc gradient computation of 22 round of optimization
# After4 disc gradient computation of 22 round of optimization
# After4 disc opt update of 22 round of optimization
# Step 4: cost = -0.4044821709394455
# End of 22 discriminator optimization
# end of 22 optimization
# Begin of 22 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.4044821709394455
# P(R|G):  0.34204167127609253
# Fidelity:  0.9212669416902366
# Trace distance:  0.3889308706553365
# ------------------------------
# Begin 23 discriminator optimization
# Before 0 disc gradient computation of 23 round of optimization
# After0 disc gradient computation of 23 round of optimization
# After0 disc opt update of 23 round of optimization
# Before 1 disc gradient computation of 23 round of optimization
# After1 disc gradient computation of 23 round of optimization
# After1 disc opt update of 23 round of optimization
# Before 2 disc gradient computation of 23 round of optimization
# After2 disc gradient computation of 23 round of optimization
# After2 disc opt update of 23 round of optimization
# Before 3 disc gradient computation of 23 round of optimization
# After3 disc gradient computation of 23 round of optimization
# After3 disc opt update of 23 round of optimization
# Before 4 disc gradient computation of 23 round of optimization
# After4 disc gradient computation of 23 round of optimization
# After4 disc opt update of 23 round of optimization
# Step 4: cost = -0.3876674175262451
# End of 23 discriminator optimization
# end of 23 optimization
# Begin of 23 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.3876674175262451
# P(R|G):  0.35301968455314636
# Fidelity:  0.9283447139838589
# Trace distance:  0.37172044874909294
# ------------------------------
# Begin 24 discriminator optimization
# Before 0 disc gradient computation of 24 round of optimization
# After0 disc gradient computation of 24 round of optimization
# After0 disc opt update of 24 round of optimization
# Before 1 disc gradient computation of 24 round of optimization
# After1 disc gradient computation of 24 round of optimization
# After1 disc opt update of 24 round of optimization
# Before 2 disc gradient computation of 24 round of optimization
# After2 disc gradient computation of 24 round of optimization
# After2 disc opt update of 24 round of optimization
# Before 3 disc gradient computation of 24 round of optimization
# After3 disc gradient computation of 24 round of optimization
# After3 disc opt update of 24 round of optimization
# Before 4 disc gradient computation of 24 round of optimization
# After4 disc gradient computation of 24 round of optimization
# After4 disc opt update of 24 round of optimization
# Step 4: cost = -0.370355024933815
# End of 24 discriminator optimization
# end of 24 optimization
# Begin of 24 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.370355024933815
# P(R|G):  0.36435510218143463
# Fidelity:  0.9352448266439094
# Trace distance:  0.35400159714860785
# ------------------------------
# Begin 25 discriminator optimization
# Before 0 disc gradient computation of 25 round of optimization
# After0 disc gradient computation of 25 round of optimization
# After0 disc opt update of 25 round of optimization
# Before 1 disc gradient computation of 25 round of optimization
# After1 disc gradient computation of 25 round of optimization
# After1 disc opt update of 25 round of optimization
# Before 2 disc gradient computation of 25 round of optimization
# After2 disc gradient computation of 25 round of optimization
# After2 disc opt update of 25 round of optimization
# Before 3 disc gradient computation of 25 round of optimization
# After3 disc gradient computation of 25 round of optimization
# After3 disc opt update of 25 round of optimization
# Before 4 disc gradient computation of 25 round of optimization
# After4 disc gradient computation of 25 round of optimization
# After4 disc opt update of 25 round of optimization
# Step 4: cost = -0.3525344431400299
# End of 25 discriminator optimization
# end of 25 optimization
# Begin of 25 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.3525344431400299
# P(R|G):  0.3760649412870407
# Fidelity:  0.9419454612339205
# Trace distance:  0.33576591259509514
# ------------------------------
# Begin 26 discriminator optimization
# Before 0 disc gradient computation of 26 round of optimization
# After0 disc gradient computation of 26 round of optimization
# After0 disc opt update of 26 round of optimization
# Before 1 disc gradient computation of 26 round of optimization
# After1 disc gradient computation of 26 round of optimization
# After1 disc opt update of 26 round of optimization
# Before 2 disc gradient computation of 26 round of optimization
# After2 disc gradient computation of 26 round of optimization
# After2 disc opt update of 26 round of optimization
# Before 3 disc gradient computation of 26 round of optimization
# After3 disc gradient computation of 26 round of optimization
# After3 disc opt update of 26 round of optimization
# Before 4 disc gradient computation of 26 round of optimization
# After4 disc gradient computation of 26 round of optimization
# After4 disc opt update of 26 round of optimization
# Step 4: cost = -0.3341984897851944
# End of 26 discriminator optimization
# end of 26 optimization
# Begin of 26 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.3341984897851944
# P(R|G):  0.38816750049591064
# Fidelity:  0.9484227526713502
# Trace distance:  0.3170083658649873
# ------------------------------
# Begin 27 discriminator optimization
# Before 0 disc gradient computation of 27 round of optimization
# After0 disc gradient computation of 27 round of optimization
# After0 disc opt update of 27 round of optimization
# Before 1 disc gradient computation of 27 round of optimization
# After1 disc gradient computation of 27 round of optimization
# After1 disc opt update of 27 round of optimization
# Before 2 disc gradient computation of 27 round of optimization
# After2 disc gradient computation of 27 round of optimization
# After2 disc opt update of 27 round of optimization
# Before 3 disc gradient computation of 27 round of optimization
# After3 disc gradient computation of 27 round of optimization
# After3 disc opt update of 27 round of optimization
# Before 4 disc gradient computation of 27 round of optimization
# After4 disc gradient computation of 27 round of optimization
# After4 disc opt update of 27 round of optimization
# Step 4: cost = -0.3153424710035324
# End of 27 discriminator optimization
# end of 27 optimization
# Begin of 27 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.3153424710035324
# P(R|G):  0.40068061649799347
# Fidelity:  0.9546508073770659
# Trace distance:  0.29772778838112535
# ------------------------------
# Begin 28 discriminator optimization
# Before 0 disc gradient computation of 28 round of optimization
# After0 disc gradient computation of 28 round of optimization
# After0 disc opt update of 28 round of optimization
# Before 1 disc gradient computation of 28 round of optimization
# After1 disc gradient computation of 28 round of optimization
# After1 disc opt update of 28 round of optimization
# Before 2 disc gradient computation of 28 round of optimization
# After2 disc gradient computation of 28 round of optimization
# After2 disc opt update of 28 round of optimization
# Before 3 disc gradient computation of 28 round of optimization
# After3 disc gradient computation of 28 round of optimization
# After3 disc opt update of 28 round of optimization
# Before 4 disc gradient computation of 28 round of optimization
# After4 disc gradient computation of 28 round of optimization
# After4 disc opt update of 28 round of optimization
# Step 4: cost = -0.29596635699272156
# End of 28 discriminator optimization
# end of 28 optimization
# Begin of 28 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.29596635699272156
# P(R|G):  0.4136244058609009
# Fidelity:  0.9606021016009647
# Trace distance:  0.27792733294839894
# ------------------------------
# Begin 29 discriminator optimization
# Before 0 disc gradient computation of 29 round of optimization
# After0 disc gradient computation of 29 round of optimization
# After0 disc opt update of 29 round of optimization
# Before 1 disc gradient computation of 29 round of optimization
# After1 disc gradient computation of 29 round of optimization
# After1 disc opt update of 29 round of optimization
# Before 2 disc gradient computation of 29 round of optimization
# After2 disc gradient computation of 29 round of optimization
# After2 disc opt update of 29 round of optimization
# Before 3 disc gradient computation of 29 round of optimization
# After3 disc gradient computation of 29 round of optimization
# After3 disc opt update of 29 round of optimization
# Before 4 disc gradient computation of 29 round of optimization
# After4 disc gradient computation of 29 round of optimization
# After4 disc opt update of 29 round of optimization
# Step 4: cost = -0.27607423067092896
# End of 29 discriminator optimization
# end of 29 optimization
# Begin of 29 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.27607423067092896
# P(R|G):  0.4270191192626953
# Fidelity:  0.9662476402699252
# Trace distance:  0.25761503631818816
# ------------------------------
# Begin 30 discriminator optimization
# Before 0 disc gradient computation of 30 round of optimization
# After0 disc gradient computation of 30 round of optimization
# After0 disc opt update of 30 round of optimization
# Before 1 disc gradient computation of 30 round of optimization
# After1 disc gradient computation of 30 round of optimization
# After1 disc opt update of 30 round of optimization
# Before 2 disc gradient computation of 30 round of optimization
# After2 disc gradient computation of 30 round of optimization
# After2 disc opt update of 30 round of optimization
# Before 3 disc gradient computation of 30 round of optimization
# After3 disc gradient computation of 30 round of optimization
# After3 disc opt update of 30 round of optimization
# Before 4 disc gradient computation of 30 round of optimization
# After4 disc gradient computation of 30 round of optimization
# After4 disc opt update of 30 round of optimization
# Step 4: cost = -0.25567397475242615
# End of 30 discriminator optimization
# end of 30 optimization
# Begin of 30 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.25567397475242615
# P(R|G):  0.4408876448869705
# Fidelity:  0.9715573780295284
# Trace distance:  0.23680430409790176
# ------------------------------
# Begin 31 discriminator optimization
# Before 0 disc gradient computation of 31 round of optimization
# After0 disc gradient computation of 31 round of optimization
# After0 disc opt update of 31 round of optimization
# Before 1 disc gradient computation of 31 round of optimization
# After1 disc gradient computation of 31 round of optimization
# After1 disc opt update of 31 round of optimization
# Before 2 disc gradient computation of 31 round of optimization
# After2 disc gradient computation of 31 round of optimization
# After2 disc opt update of 31 round of optimization
# Before 3 disc gradient computation of 31 round of optimization
# After3 disc gradient computation of 31 round of optimization
# After3 disc opt update of 31 round of optimization
# Before 4 disc gradient computation of 31 round of optimization
# After4 disc gradient computation of 31 round of optimization
# After4 disc opt update of 31 round of optimization
# Step 4: cost = -0.23478034138679504
# End of 31 discriminator optimization
# end of 31 optimization
# Begin of 31 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.23478034138679504
# P(R|G):  0.4552539736032486
# Fidelity:  0.9765006414765436
# Trace distance:  0.2155145322319709
# ------------------------------
# Begin 32 discriminator optimization
# Before 0 disc gradient computation of 32 round of optimization
# After0 disc gradient computation of 32 round of optimization
# After0 disc opt update of 32 round of optimization
# Before 1 disc gradient computation of 32 round of optimization
# After1 disc gradient computation of 32 round of optimization
# After1 disc opt update of 32 round of optimization
# Before 2 disc gradient computation of 32 round of optimization
# After2 disc gradient computation of 32 round of optimization
# After2 disc opt update of 32 round of optimization
# Before 3 disc gradient computation of 32 round of optimization
# After3 disc gradient computation of 32 round of optimization
# After3 disc opt update of 32 round of optimization
# Before 4 disc gradient computation of 32 round of optimization
# After4 disc gradient computation of 32 round of optimization
# After4 disc opt update of 32 round of optimization
# Step 4: cost = -0.21341381967067719
# End of 32 discriminator optimization
# end of 32 optimization
# Begin of 32 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.21341381967067719
# P(R|G):  0.47014617919921875
# Fidelity:  0.9810466362273423
# Trace distance:  0.19377176664059392
# ------------------------------
# Begin 33 discriminator optimization
# Before 0 disc gradient computation of 33 round of optimization
# After0 disc gradient computation of 33 round of optimization
# After0 disc opt update of 33 round of optimization
# Before 1 disc gradient computation of 33 round of optimization
# After1 disc gradient computation of 33 round of optimization
# After1 disc opt update of 33 round of optimization
# Before 2 disc gradient computation of 33 round of optimization
# After2 disc gradient computation of 33 round of optimization
# After2 disc opt update of 33 round of optimization
# Before 3 disc gradient computation of 33 round of optimization
# After3 disc gradient computation of 33 round of optimization
# After3 disc opt update of 33 round of optimization
# Before 4 disc gradient computation of 33 round of optimization
# After4 disc gradient computation of 33 round of optimization
# After4 disc opt update of 33 round of optimization
# Step 4: cost = -0.19160096347332
# End of 33 discriminator optimization
# end of 33 optimization
# Begin of 33 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.19160096347332
# P(R|G):  0.48559606075286865
# Fidelity:  0.9851650158247072
# Trace distance:  0.17160974104022286
# ------------------------------
# Begin 34 discriminator optimization
# Before 0 disc gradient computation of 34 round of optimization
# After0 disc gradient computation of 34 round of optimization
# After0 disc opt update of 34 round of optimization
# Before 1 disc gradient computation of 34 round of optimization
# After1 disc gradient computation of 34 round of optimization
# After1 disc opt update of 34 round of optimization
# Before 2 disc gradient computation of 34 round of optimization
# After2 disc gradient computation of 34 round of optimization
# After2 disc opt update of 34 round of optimization
# Before 3 disc gradient computation of 34 round of optimization
# After3 disc gradient computation of 34 round of optimization
# After3 disc opt update of 34 round of optimization
# Before 4 disc gradient computation of 34 round of optimization
# After4 disc gradient computation of 34 round of optimization
# After4 disc opt update of 34 round of optimization
# Step 4: cost = -0.16937673091888428
# End of 34 discriminator optimization
# end of 34 optimization
# Begin of 34 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.16937673091888428
# P(R|G):  0.5016413331031799
# Fidelity:  0.9888264475836447
# Trace distance:  0.14907134185584298
# ------------------------------
# Begin 35 discriminator optimization
# Before 0 disc gradient computation of 35 round of optimization
# After0 disc gradient computation of 35 round of optimization
# After0 disc opt update of 35 round of optimization
# Before 1 disc gradient computation of 35 round of optimization
# After1 disc gradient computation of 35 round of optimization
# After1 disc opt update of 35 round of optimization
# Before 2 disc gradient computation of 35 round of optimization
# After2 disc gradient computation of 35 round of optimization
# After2 disc opt update of 35 round of optimization
# Before 3 disc gradient computation of 35 round of optimization
# After3 disc gradient computation of 35 round of optimization
# After3 disc opt update of 35 round of optimization
# Before 4 disc gradient computation of 35 round of optimization
# After4 disc gradient computation of 35 round of optimization
# After4 disc opt update of 35 round of optimization
# Step 4: cost = -0.14678357541561127
# End of 35 discriminator optimization
# end of 35 optimization
# Begin of 35 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.14678357541561127
# P(R|G):  0.5183271169662476
# Fidelity:  0.9920033523447754
# Trace distance:  0.12621152457968324
# ------------------------------
# Begin 36 discriminator optimization
# Before 0 disc gradient computation of 36 round of optimization
# After0 disc gradient computation of 36 round of optimization
# After0 disc opt update of 36 round of optimization
# Before 1 disc gradient computation of 36 round of optimization
# After1 disc gradient computation of 36 round of optimization
# After1 disc opt update of 36 round of optimization
# Before 2 disc gradient computation of 36 round of optimization
# After2 disc gradient computation of 36 round of optimization
# After2 disc opt update of 36 round of optimization
# Before 3 disc gradient computation of 36 round of optimization
# After3 disc gradient computation of 36 round of optimization
# After3 disc opt update of 36 round of optimization
# Before 4 disc gradient computation of 36 round of optimization
# After4 disc gradient computation of 36 round of optimization
# After4 disc opt update of 36 round of optimization
# Step 4: cost = -0.12387345731258392
# End of 36 discriminator optimization
# end of 36 optimization
# Begin of 36 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.12387345731258392
# P(R|G):  0.5357089787721634
# Fidelity:  0.9946706241981645
# Trace distance:  0.10310358556924051
# ------------------------------
# Begin 37 discriminator optimization
# Before 0 disc gradient computation of 37 round of optimization
# After0 disc gradient computation of 37 round of optimization
# After0 disc opt update of 37 round of optimization
# Before 1 disc gradient computation of 37 round of optimization
# After1 disc gradient computation of 37 round of optimization
# After1 disc opt update of 37 round of optimization
# Before 2 disc gradient computation of 37 round of optimization
# After2 disc gradient computation of 37 round of optimization
# ...
# After4 disc gradient computation of 87 round of optimization
# After4 disc opt update of 87 round of optimization
# Step 4: cost = 0.008525550365447998
# End of 87 discriminator optimization
# end of 87 optimization
# Begin of 87 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  -0.008525550365447998
# P(R|G):  0.9208252094686031
# Fidelity:  0.9993731765564131
# Trace distance:  0.0354015916417348
# ------------------------------
# Begin 88 discriminator optimization
# Before 0 disc gradient computation of 88 round of optimization
# After0 disc gradient computation of 88 round of optimization
# After0 disc opt update of 88 round of optimization
# Before 1 disc gradient computation of 88 round of optimization
# After1 disc gradient computation of 88 round of optimization
# After1 disc opt update of 88 round of optimization
# Before 2 disc gradient computation of 88 round of optimization
# After2 disc gradient computation of 88 round of optimization
# After2 disc opt update of 88 round of optimization
# Before 3 disc gradient computation of 88 round of optimization
# After3 disc gradient computation of 88 round of optimization
# After3 disc opt update of 88 round of optimization
# Before 4 disc gradient computation of 88 round of optimization
# After4 disc gradient computation of 88 round of optimization
# After4 disc opt update of 88 round of optimization
# Step 4: cost = 0.014510739594697952
# End of 88 discriminator optimization
# end of 88 optimization
# Begin of 88 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  -0.014510739594697952
# P(R|G):  0.9335595518350601
# Fidelity:  0.9989676485203018
# Trace distance:  0.04542727385414118
# ------------------------------
# Begin 89 discriminator optimization
# Before 0 disc gradient computation of 89 round of optimization
# After0 disc gradient computation of 89 round of optimization
# After0 disc opt update of 89 round of optimization
# Before 1 disc gradient computation of 89 round of optimization
# After1 disc gradient computation of 89 round of optimization
# After1 disc opt update of 89 round of optimization
# Before 2 disc gradient computation of 89 round of optimization
# After2 disc gradient computation of 89 round of optimization
# After2 disc opt update of 89 round of optimization
# Before 3 disc gradient computation of 89 round of optimization
# After3 disc gradient computation of 89 round of optimization
# After3 disc opt update of 89 round of optimization
# Before 4 disc gradient computation of 89 round of optimization
# After4 disc gradient computation of 89 round of optimization
# After4 disc opt update of 89 round of optimization
# Step 4: cost = 0.018656613305211067
# End of 89 discriminator optimization
# end of 89 optimization
# Begin of 89 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  -0.018656613305211067
# P(R|G):  0.9466865099966526
# Fidelity:  0.9984901136027872
# Trace distance:  0.05493191375092716
# ------------------------------
# Begin 90 discriminator optimization
# Before 0 disc gradient computation of 90 round of optimization
# After0 disc gradient computation of 90 round of optimization
# After0 disc opt update of 90 round of optimization
# Before 1 disc gradient computation of 90 round of optimization
# After1 disc gradient computation of 90 round of optimization
# After1 disc opt update of 90 round of optimization
# Before 2 disc gradient computation of 90 round of optimization
# After2 disc gradient computation of 90 round of optimization
# After2 disc opt update of 90 round of optimization
# Before 3 disc gradient computation of 90 round of optimization
# After3 disc gradient computation of 90 round of optimization
# After3 disc opt update of 90 round of optimization
# Before 4 disc gradient computation of 90 round of optimization
# After4 disc gradient computation of 90 round of optimization
# After4 disc opt update of 90 round of optimization
# Step 4: cost = 0.020650215446949005
# End of 90 discriminator optimization
# end of 90 optimization
# Begin of 90 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  -0.020650215446949005
# P(R|G):  0.9591971226036549
# Fidelity:  0.9979987602448801
# Trace distance:  0.06323349230971209
# ------------------------------
# Begin 91 discriminator optimization
# Before 0 disc gradient computation of 91 round of optimization
# After0 disc gradient computation of 91 round of optimization
# After0 disc opt update of 91 round of optimization
# Before 1 disc gradient computation of 91 round of optimization
# After1 disc gradient computation of 91 round of optimization
# After1 disc opt update of 91 round of optimization
# Before 2 disc gradient computation of 91 round of optimization
# After2 disc gradient computation of 91 round of optimization
# After2 disc opt update of 91 round of optimization
# Before 3 disc gradient computation of 91 round of optimization
# After3 disc gradient computation of 91 round of optimization
# After3 disc opt update of 91 round of optimization
# Before 4 disc gradient computation of 91 round of optimization
# After4 disc gradient computation of 91 round of optimization
# After4 disc opt update of 91 round of optimization
# Step 4: cost = 0.020360825583338737
# End of 91 discriminator optimization
# end of 91 optimization
# Begin of 91 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  -0.020360825583338737
# P(R|G):  0.9700653897598386
# Fidelity:  0.997551517992688
# Trace distance:  0.06993554687482462
# ------------------------------
# Begin 92 discriminator optimization
# Before 0 disc gradient computation of 92 round of optimization
# After0 disc gradient computation of 92 round of optimization
# After0 disc opt update of 92 round of optimization
# Before 1 disc gradient computation of 92 round of optimization
# After1 disc gradient computation of 92 round of optimization
# After1 disc opt update of 92 round of optimization
# Before 2 disc gradient computation of 92 round of optimization
# After2 disc gradient computation of 92 round of optimization
# After2 disc opt update of 92 round of optimization
# Before 3 disc gradient computation of 92 round of optimization
# After3 disc gradient computation of 92 round of optimization
# After3 disc opt update of 92 round of optimization
# Before 4 disc gradient computation of 92 round of optimization
# After4 disc gradient computation of 92 round of optimization
# After4 disc opt update of 92 round of optimization
# Step 4: cost = 0.017892291769385338
# End of 92 discriminator optimization
# end of 92 optimization
# Begin of 92 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  -0.017892291769385338
# P(R|G):  0.9783623376861215
# Fidelity:  0.9971992511975307
# Trace distance:  0.07479077656093788
# ------------------------------
# Begin 93 discriminator optimization
# Before 0 disc gradient computation of 93 round of optimization
# After0 disc gradient computation of 93 round of optimization
# After0 disc opt update of 93 round of optimization
# Before 1 disc gradient computation of 93 round of optimization
# After1 disc gradient computation of 93 round of optimization
# After1 disc opt update of 93 round of optimization
# Before 2 disc gradient computation of 93 round of optimization
# After2 disc gradient computation of 93 round of optimization
# After2 disc opt update of 93 round of optimization
# Before 3 disc gradient computation of 93 round of optimization
# After3 disc gradient computation of 93 round of optimization
# After3 disc opt update of 93 round of optimization
# Before 4 disc gradient computation of 93 round of optimization
# After4 disc gradient computation of 93 round of optimization
# After4 disc opt update of 93 round of optimization
# Step 4: cost = 0.013615266419947147
# End of 93 discriminator optimization
# end of 93 optimization
# Begin of 93 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  -0.013615266419947147
# P(R|G):  0.9834063621237874
# Fidelity:  0.9969793342506683
# Trace distance:  0.07766740432377978
# ------------------------------
# Begin 94 discriminator optimization
# Before 0 disc gradient computation of 94 round of optimization
# After0 disc gradient computation of 94 round of optimization
# After0 disc opt update of 94 round of optimization
# Before 1 disc gradient computation of 94 round of optimization
# After1 disc gradient computation of 94 round of optimization
# After1 disc opt update of 94 round of optimization
# Before 2 disc gradient computation of 94 round of optimization
# After2 disc gradient computation of 94 round of optimization
# After2 disc opt update of 94 round of optimization
# Before 3 disc gradient computation of 94 round of optimization
# After3 disc gradient computation of 94 round of optimization
# After3 disc opt update of 94 round of optimization
# Before 4 disc gradient computation of 94 round of optimization
# After4 disc gradient computation of 94 round of optimization
# After4 disc opt update of 94 round of optimization
# Step 4: cost = 0.008135306648910046
# End of 94 discriminator optimization
# end of 94 optimization
# Begin of 94 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  -0.008135306648910046
# P(R|G):  0.9849094310775399
# Fidelity:  0.9969107279514984
# Trace distance:  0.07854312974770786
# ------------------------------
# Begin 95 discriminator optimization
# Before 0 disc gradient computation of 95 round of optimization
# After0 disc gradient computation of 95 round of optimization
# After0 disc opt update of 95 round of optimization
# Before 1 disc gradient computation of 95 round of optimization
# After1 disc gradient computation of 95 round of optimization
# After1 disc opt update of 95 round of optimization
# Before 2 disc gradient computation of 95 round of optimization
# After2 disc gradient computation of 95 round of optimization
# After2 disc opt update of 95 round of optimization
# Before 3 disc gradient computation of 95 round of optimization
# After3 disc gradient computation of 95 round of optimization
# After3 disc opt update of 95 round of optimization
# Before 4 disc gradient computation of 95 round of optimization
# After4 disc gradient computation of 95 round of optimization
# After4 disc opt update of 95 round of optimization
# Step 4: cost = 0.0022051678970456123
# End of 95 discriminator optimization
# end of 95 optimization
# Begin of 95 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  -0.0022051678970456123
# P(R|G):  0.9830571543425322
# Fidelity:  0.9969922625258464
# Trace distance:  0.07750115136947576
# ------------------------------
# Begin 96 discriminator optimization
# Before 0 disc gradient computation of 96 round of optimization
# After0 disc gradient computation of 96 round of optimization
# After0 disc opt update of 96 round of optimization
# Before 1 disc gradient computation of 96 round of optimization
# After1 disc gradient computation of 96 round of optimization
# After1 disc opt update of 96 round of optimization
# Before 2 disc gradient computation of 96 round of optimization
# After2 disc gradient computation of 96 round of optimization
# After2 disc opt update of 96 round of optimization
# Before 3 disc gradient computation of 96 round of optimization
# After3 disc gradient computation of 96 round of optimization
# After3 disc opt update of 96 round of optimization
# Before 4 disc gradient computation of 96 round of optimization
# After4 disc gradient computation of 96 round of optimization
# After4 disc opt update of 96 round of optimization
# Step 4: cost = -0.0034135794267058372
# End of 96 discriminator optimization
# end of 96 optimization
# Begin of 96 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.0034135794267058372
# P(R|G):  0.9784836769104004
# Fidelity:  0.9972045722496417
# Trace distance:  0.0747197502967496
# ------------------------------
# Begin 97 discriminator optimization
# Before 0 disc gradient computation of 97 round of optimization
# After0 disc gradient computation of 97 round of optimization
# After0 disc opt update of 97 round of optimization
# Before 1 disc gradient computation of 97 round of optimization
# After1 disc gradient computation of 97 round of optimization
# After1 disc opt update of 97 round of optimization
# Before 2 disc gradient computation of 97 round of optimization
# After2 disc gradient computation of 97 round of optimization
# After2 disc opt update of 97 round of optimization
# Before 3 disc gradient computation of 97 round of optimization
# After3 disc gradient computation of 97 round of optimization
# After3 disc opt update of 97 round of optimization
# Before 4 disc gradient computation of 97 round of optimization
# After4 disc gradient computation of 97 round of optimization
# After4 disc opt update of 97 round of optimization
# Step 4: cost = -0.008083724416792393
# End of 97 discriminator optimization
# end of 97 optimization
# Begin of 97 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.008083724416792393
# P(R|G):  0.9721342604607344
# Fidelity:  0.9975149255350069
# Trace distance:  0.07045547058170806
# ------------------------------
# Begin 98 discriminator optimization
# Before 0 disc gradient computation of 98 round of optimization
# After0 disc gradient computation of 98 round of optimization
# After0 disc opt update of 98 round of optimization
# Before 1 disc gradient computation of 98 round of optimization
# After1 disc gradient computation of 98 round of optimization
# After1 disc opt update of 98 round of optimization
# Before 2 disc gradient computation of 98 round of optimization
# After2 disc gradient computation of 98 round of optimization
# After2 disc opt update of 98 round of optimization
# Before 3 disc gradient computation of 98 round of optimization
# After3 disc gradient computation of 98 round of optimization
# After3 disc opt update of 98 round of optimization
# Before 4 disc gradient computation of 98 round of optimization
# After4 disc gradient computation of 98 round of optimization
# After4 disc opt update of 98 round of optimization
# Step 4: cost = -0.011385522782802582
# End of 98 discriminator optimization
# end of 98 optimization
# Begin of 98 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.011385522782802582
# P(R|G):  0.9650745429098606
# Fidelity:  0.9978836435523013
# Trace distance:  0.06502491398086065
# ------------------------------
# Begin 99 discriminator optimization
# Before 0 disc gradient computation of 99 round of optimization
# After0 disc gradient computation of 99 round of optimization
# After0 disc opt update of 99 round of optimization
# Before 1 disc gradient computation of 99 round of optimization
# After1 disc gradient computation of 99 round of optimization
# After1 disc opt update of 99 round of optimization
# Before 2 disc gradient computation of 99 round of optimization
# After2 disc gradient computation of 99 round of optimization
# After2 disc opt update of 99 round of optimization
# Before 3 disc gradient computation of 99 round of optimization
# After3 disc gradient computation of 99 round of optimization
# After3 disc opt update of 99 round of optimization
# Before 4 disc gradient computation of 99 round of optimization
# After4 disc gradient computation of 99 round of optimization
# After4 disc opt update of 99 round of optimization
# Step 4: cost = -0.013142295181751251
# End of 99 discriminator optimization
# end of 99 optimization
# Begin of 99 generator optimization
# Before gen gradient computation
# After gen gradient computation
# After gen opt update
# P(R|R)-P(R|G):  0.013142295181751251
# P(R|G):  0.9583038818091154
# Fidelity:  0.9982702687265549
# Trace distance:  0.05879175602592382
# ------------------------------

# %%
F = np.array(F)
Gen_cost = np.array(Gen_cost)
Disc_cost = np.array(Disc_cost)
Trace_d = np.array(Trace_d)

# %%
plt.plot(F, label='Fidelity')
plt.plot(Gen_cost, label='P(R|G)')
plt.plot(Disc_cost, label='P(R|R)-P(R|G)')
plt.plot(Trace_d, label='Trace distance')
plt.ylim([-0.01,1.1])
plt.xlabel('Turns (5D+1G)') 
plt.title("1-qubit $|\psi>$ metrics")
plt.legend()
plt.savefig('1qubitlearning_parameter_shift.png', format='png')

# %%
b = qt.Bloch()

final_real = F_Tr_state(real_params,gen_weights)[2]
final_gen =  F_Tr_state(real_params,gen_weights)[3]
b.add_states(final_real)
b.add_states(final_gen)
b.add_states(States[0])
b.render()
plt.savefig('blochsphere.png', format='png')

# %%
F_Tr_state(real_params,gen_weights)[2]
