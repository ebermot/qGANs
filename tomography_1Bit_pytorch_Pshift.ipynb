# %%
import pennylane as qml
from pennylane import numpy as np
import tensorflow as tf
import cirq

import optim
import torch as torch

# %% [markdown]
# Any computational object that can apply quantum operations and return a measurement value is called a quantum device.
#
# In PennyLane, a device could be a hardware device (such as the IBM QX4, via the PennyLane-PQ plugin), or a software simulator (such as Strawberry Fields, via the PennyLane-SF plugin).

# %%
dev = qml.device('default.qubit', wires=1)

# %% [markdown]
# Unitary = arbitrary rotation

# %%
phi = np.pi / 6
theta = np.pi / 2
omega = np.pi / 7
##phi = 0
##theta = 0
##omega = 0
angles = [phi,theta,omega]

def real(angles, **kwargs):
    qml.Rot(*angles, wires=0)

# %% [markdown]
# Generator

# %%
def generator(w, **kwargs):
    qml.RZ(w[0], wires=0)
    qml.RY(w[1], wires=0)
    qml.RZ(w[2], wires=0)

# %% [markdown]
# Discriminators: DI chooses the input, DO is standard

# %%
def DI(w):
    qml.RX(w[0], wires=0)
    qml.RY(w[1], wires=0)
    qml.RZ(w[2], wires=0)

def DO(w):
    qml.RZ(w[0], wires=0)
    qml.RY(w[1], wires=0)
    qml.RZ(w[2], wires=0)

# %% [markdown]
# 2 nodes:  1 for data-discriminator
#           1 for generator-discriminator

# %%
@qml.qnode(dev, interface="torch", diff_method = 'parameter-shift')
def real_disc_circuit(angles, disc_weights):
    #DI(disc_weights[9:18])
    real(angles)
    DO(disc_weights[0:3])
    return qml.expval(qml.PauliZ(0))

@qml.qnode(dev, interface="torch", diff_method = 'parameter-shift')
def gen_disc_circuit(gen_weights, disc_weights):
    #DI(disc_weights[9:18])
    generator(gen_weights)
    DO(disc_weights[0:3])
    return qml.expval(qml.PauliZ(0))

##grad computing node, bc the pytorch interface does strange stuff
@qml.qnode(dev, diff_method = 'parameter-shift')
def real_disc_circuit_grad(angles, disc_weights):
    #DI(disc_weights[9:18])
    real(angles)
    DO(disc_weights[0:3])
    return qml.expval(qml.PauliZ(0))

@qml.qnode(dev, diff_method = 'parameter-shift')
def gen_disc_circuit_grad(gen_weights, disc_weights):
    #DI(disc_weights[9:18])
    generator(gen_weights)
    DO(disc_weights[0:3])
    return qml.expval(qml.PauliZ(0))

# %% [markdown]
# Cost Functions

# %%
def prob_real_true(disc_weights):
    true_disc_output = real_disc_circuit(angles, disc_weights)
    
    # convert to probability
    prob_real_true = (true_disc_output + 1) / 2
    return prob_real_true


def prob_fake_true(gen_weights, disc_weights):
    
    fake_disc_output = gen_disc_circuit(gen_weights, disc_weights)
    # convert to probability
    prob_fake_true = (fake_disc_output + 1) / 2
    return prob_fake_true


def disc_cost(disc_weights, gen_weights):
    cost = prob_fake_true(gen_weights, disc_weights) - prob_real_true(disc_weights)
    return cost


def gen_cost(disc_weights, gen_weights):
    return -prob_fake_true(gen_weights, disc_weights)

# %% [markdown]
# Training Initialization:

# %%
phi = np.pi / 6
theta = np.pi / 2
omega = np.pi / 7
np.random.seed(0)
eps = 1e-2
init_gen_weights = np.array([np.pi] + [0] * 2) + \
                   np.random.normal(scale=eps, size=(3,))
init_disc_weights = np.random.normal(size=(3,))

gen_weights_grad  = torch.tensor(init_gen_weights, requires_grad=True)
disc_weights_grad = torch.tensor(init_disc_weights, requires_grad=True)

# %% [markdown]
# Running training

# %%
N = 100     #Number of training cycles
steps = 1 #Number of steps for generator training
ratio = 5  #gen/disc training ratio

for i in range (N):
    
    #training discriminator
    gen_weights_non_grad = torch.tensor(gen_weights_grad.detach().numpy(), requires_grad = False)
    opt = optim.OAdam([disc_weights_grad, gen_weights_non_grad], lr = 0.1)
    
    def closure():
        opt.zero_grad()
        
        loss = disc_cost(disc_weights_grad, gen_weights_non_grad)
        
        disc_weights=np.array( list(disc_weights_grad.detach().numpy()) ,    requires_grad=True )
        gen_weights =np.array( list(gen_weights_non_grad.detach().numpy()) , requires_grad=False)
        
        grad_gen_circuit_disc =qml.grad(gen_disc_circuit_grad,  argnum=1)
        grad_real_disc_circuit=qml.grad(real_disc_circuit_grad, argnum=1) 
        grad_fn_disc= grad_gen_circuit_disc(gen_weights, disc_weights)-grad_real_disc_circuit(angles, disc_weights)

        disc_weights_grad.grad = torch.tensor(grad_fn_disc)

        return loss

    for j in range(steps*ratio):
        opt.step(closure)
        if (j+1)%5==0:
            print('step : ',j, ' discriminator cost : ',disc_cost(disc_weights_grad, gen_weights_non_grad).item())
    print('discriminator trained')
    
    #training generator
    disc_weights_non_grad = torch.tensor(disc_weights_grad.detach().numpy(), requires_grad = False)
    opt = optim.OAdam([disc_weights_non_grad, gen_weights_grad], lr = 0.1)

    def closure():
        opt.zero_grad()
        loss = gen_cost(disc_weights_non_grad, gen_weights_grad)
        
        disc_weights=np.array( list(disc_weights_grad.detach().numpy()) ,    requires_grad=False)
        gen_weights =np.array( list(gen_weights_non_grad.detach().numpy()) , requires_grad=True)
        
        grad_fn_gen=-qml.grad(gen_disc_circuit_grad, argnum=0)(gen_weights, disc_weights)
        
        gen_weights_grad.grad = torch.tensor(grad_fn_gen)

        return loss

    for j in range(steps):
        opt.step(closure)
        if (j+1)%5==0:
            print('step : ',j, ' generator cost : ',gen_cost(disc_weights_non_grad, gen_weights_grad).item())
        
    print('end of cycle number : ', i+1)
# Out:
# step :  4  discriminator cost :  0.01766390701000964
# discriminator trained
# end of cycle number :  1
# step :  4  discriminator cost :  0.08544712738671306
# discriminator trained
# end of cycle number :  2
# step :  4  discriminator cost :  -0.0469636514739753
# discriminator trained
# end of cycle number :  3
# step :  4  discriminator cost :  -0.229681082688741
# discriminator trained
# end of cycle number :  4
# step :  4  discriminator cost :  -0.2197763329951518
# discriminator trained
# end of cycle number :  5
# step :  4  discriminator cost :  -0.17505745723383537
# discriminator trained
# end of cycle number :  6
# step :  4  discriminator cost :  -0.04874061381585815
# discriminator trained
# end of cycle number :  7
# step :  4  discriminator cost :  0.039632097177686454
# discriminator trained
# end of cycle number :  8
# step :  4  discriminator cost :  -0.012461646125006554
# discriminator trained
# end of cycle number :  9
# step :  4  discriminator cost :  -0.03687464720804634
# discriminator trained
# end of cycle number :  10
# step :  4  discriminator cost :  -0.02664513110337985
# discriminator trained
# end of cycle number :  11
# step :  4  discriminator cost :  -0.03739713076160711
# discriminator trained
# end of cycle number :  12
# step :  4  discriminator cost :  -0.02646131258932971
# discriminator trained
# end of cycle number :  13
# step :  4  discriminator cost :  -0.037896409956175825
# discriminator trained
# end of cycle number :  14
# step :  4  discriminator cost :  -0.026284211665725477
# discriminator trained
# end of cycle number :  15
# step :  4  discriminator cost :  -0.0383736000094842
# discriminator trained
# end of cycle number :  16
# step :  4  discriminator cost :  -0.026113652978907442
# discriminator trained
# end of cycle number :  17
# step :  4  discriminator cost :  -0.03882975472740702
# discriminator trained
# end of cycle number :  18
# step :  4  discriminator cost :  -0.025949460158991466
# discriminator trained
# end of cycle number :  19
# step :  4  discriminator cost :  -0.039265870452194096
# discriminator trained
# end of cycle number :  20
# step :  4  discriminator cost :  -0.025791456627518472
# discriminator trained
# end of cycle number :  21
# step :  4  discriminator cost :  -0.03968288971308864
# discriminator trained
# end of cycle number :  22
# step :  4  discriminator cost :  -0.02563946629202185
# discriminator trained
# end of cycle number :  23
# step :  4  discriminator cost :  -0.04008170460578253
# discriminator trained
# end of cycle number :  24
# step :  4  discriminator cost :  -0.02549331414119549
# discriminator trained
# end of cycle number :  25
# step :  4  discriminator cost :  -0.04046315992439842
# discriminator trained
# end of cycle number :  26
# step :  4  discriminator cost :  -0.025352826752672586
# discriminator trained
# end of cycle number :  27
# step :  4  discriminator cost :  -0.04082805606717532
# discriminator trained
# end of cycle number :  28
# step :  4  discriminator cost :  -0.025217832724024114
# discriminator trained
# end of cycle number :  29
# step :  4  discriminator cost :  -0.041177151734935524
# discriminator trained
# end of cycle number :  30
# step :  4  discriminator cost :  -0.02508816303630601
# discriminator trained
# end of cycle number :  31
# step :  4  discriminator cost :  -0.04151116643947783
# discriminator trained
# end of cycle number :  32
# step :  4  discriminator cost :  -0.024963651358358763
# discriminator trained
# end of cycle number :  33
# step :  4  discriminator cost :  -0.04183078283740804
# discriminator trained
# end of cycle number :  34
# step :  4  discriminator cost :  -0.02484413429915111
# discriminator trained
# end of cycle number :  35
# step :  4  discriminator cost :  -0.042136648903407514
# discriminator trained
# end of cycle number :  36
# step :  4  discriminator cost :  -0.024729451614471043
# discriminator trained
# end of cycle number :  37
# step :  4  discriminator cost :  -0.04242937995569229
# discriminator trained
# end of cycle number :  38
# step :  4  discriminator cost :  -0.024619446373683518
# discriminator trained
# end of cycle number :  39
# step :  4  discriminator cost :  -0.042709560545162395
# discriminator trained
# end of cycle number :  40
# step :  4  discriminator cost :  -0.024513965091464973
# discriminator trained
# end of cycle number :  41
# step :  4  discriminator cost :  -0.04297774621880557
# discriminator trained
# end of cycle number :  42
# step :  4  discriminator cost :  -0.024412857828919332
# discriminator trained
# end of cycle number :  43
# step :  4  discriminator cost :  -0.04323446516687701
# discriminator trained
# end of cycle number :  44
# step :  4  discriminator cost :  -0.02431597826796017
# discriminator trained
# end of cycle number :  45
# step :  4  discriminator cost :  -0.04348021976263361
# discriminator trained
# end of cycle number :  46
# step :  4  discriminator cost :  -0.02422318376235688
# discriminator trained
# end of cycle number :  47
# step :  4  discriminator cost :  -0.04371548800261538
# discriminator trained
# end of cycle number :  48
# step :  4  discriminator cost :  -0.02413433536850451
# discriminator trained
# end of cycle number :  49
# step :  4  discriminator cost :  -0.043940724854753976
# discriminator trained
# end of cycle number :  50
# step :  4  discriminator cost :  -0.024049297858547702
# discriminator trained
# end of cycle number :  51
# step :  4  discriminator cost :  -0.04415636352106711
# discriminator trained
# end of cycle number :  52
# step :  4  discriminator cost :  -0.02396793971825495
# discriminator trained
# end of cycle number :  53
# step :  4  discriminator cost :  -0.044362816621054235
# discriminator trained
# end of cycle number :  54
# step :  4  discriminator cost :  -0.02389013313171562
# discriminator trained
# end of cycle number :  55
# step :  4  discriminator cost :  -0.04456047730143986
# discriminator trained
# end of cycle number :  56
# step :  4  discriminator cost :  -0.02381575395471014
# discriminator trained
# end of cycle number :  57
# step :  4  discriminator cost :  -0.04474972027750723
# discriminator trained
# end of cycle number :  58
# step :  4  discriminator cost :  -0.02374468167837962
# discriminator trained
# end of cycle number :  59
# step :  4  discriminator cost :  -0.04493090281075329
# discriminator trained
# end of cycle number :  60
# step :  4  discriminator cost :  -0.023676799384645175
# discriminator trained
# end of cycle number :  61
# step :  4  discriminator cost :  -0.04510436562732234
# discriminator trained
# end of cycle number :  62
# step :  4  discriminator cost :  -0.0236119936946374
# discriminator trained
# end of cycle number :  63
# step :  4  discriminator cost :  -0.04527043378124784
# discriminator trained
# end of cycle number :  64
# step :  4  discriminator cost :  -0.02355015471126498
# discriminator trained
# end of cycle number :  65
# step :  4  discriminator cost :  -0.04542941746629514
# discriminator trained
# end of cycle number :  66
# step :  4  discriminator cost :  -0.02349117595692074
# discriminator trained
# end of cycle number :  67
# step :  4  discriminator cost :  -0.04558161277982298
# discriminator trained
# end of cycle number :  68
# step :  4  discriminator cost :  -0.023434954307193445
# discriminator trained
# end of cycle number :  69
# step :  4  discriminator cost :  -0.04572730244191414
# discriminator trained
# end of cycle number :  70
# step :  4  discriminator cost :  -0.023381389921342643
# discriminator trained
# end of cycle number :  71
# step :  4  discriminator cost :  -0.04586675647272864
# discriminator trained
# end of cycle number :  72
# step :  4  discriminator cost :  -0.023330386170237194
# discriminator trained
# end of cycle number :  73
# step :  4  discriminator cost :  -0.04600023283083943
# discriminator trained
# end of cycle number :  74
# step :  4  discriminator cost :  -0.023281849562322487
# discriminator trained
# end of cycle number :  75
# step :  4  discriminator cost :  -0.046127978015045534
# discriminator trained
# end of cycle number :  76
# step :  4  discriminator cost :  -0.023235689668180015
# discriminator trained
# end of cycle number :  77
# step :  4  discriminator cost :  -0.046250227632103624
# discriminator trained
# end of cycle number :  78
# step :  4  discriminator cost :  -0.023191819044080297
# discriminator trained
# end of cycle number :  79
# step :  4  discriminator cost :  -0.04636720693250174
# discriminator trained
# end of cycle number :  80
# step :  4  discriminator cost :  -0.023150153154982256
# discriminator trained
# end of cycle number :  81
# step :  4  discriminator cost :  -0.04647913131633885
# discriminator trained
# end of cycle number :  82
# step :  4  discriminator cost :  -0.023110610297288448
# discriminator trained
# end of cycle number :  83
# step :  4  discriminator cost :  -0.04658620681119996
# discriminator trained
# end of cycle number :  84
# step :  4  discriminator cost :  -0.023073111521679457
# discriminator trained
# end of cycle number :  85
# step :  4  discriminator cost :  -0.04668863052376515
# discriminator trained
# end of cycle number :  86
# step :  4  discriminator cost :  -0.02303758055628513
# discriminator trained
# end of cycle number :  87
# step :  4  discriminator cost :  -0.04678659106681127
# discriminator trained
# end of cycle number :  88
# step :  4  discriminator cost :  -0.023003943730407705
# discriminator trained
# end of cycle number :  89
# step :  4  discriminator cost :  -0.04688026896310471
# discriminator trained
# end of cycle number :  90
# step :  4  discriminator cost :  -0.022972129899007987
# discriminator trained
# end of cycle number :  91
# step :  4  discriminator cost :  -0.04696983702760704
# discriminator trained
# end of cycle number :  92
# step :  4  discriminator cost :  -0.022942070368107026
# discriminator trained
# end of cycle number :  93
# step :  4  discriminator cost :  -0.047055460729319876
# discriminator trained
# end of cycle number :  94
# step :  4  discriminator cost :  -0.022913698821252493
# discriminator trained
# end of cycle number :  95
# step :  4  discriminator cost :  -0.04713729853399462
# discriminator trained
# end of cycle number :  96
# step :  4  discriminator cost :  -0.02288695124716833
# discriminator trained
# end of cycle number :  97
# step :  4  discriminator cost :  -0.04721550222882487
# discriminator trained
# end of cycle number :  98
# step :  4  discriminator cost :  -0.02286176586867661
# discriminator trained
# end of cycle number :  99
# step :  4  discriminator cost :  -0.04729021723026494
# discriminator trained
# end of cycle number :  100

# %%
print("Prob(real classified as real): ", prob_real_true(disc_weights_grad).item())
# Out:
# Prob(real classified as real):  0.939634237336783

# %%
print("Prob(fake classified as real): ", prob_fake_true(gen_weights_grad, disc_weights_grad).item())
# Out:
# Prob(fake classified as real):  0.9597010098586476

# %% [markdown]
# Comparing output for |0> and printing tthe rotation params of the generator:

# %%
obs = [qml.PauliX(0), qml.PauliY(0), qml.PauliZ(0)]

bloch_vector_real = qml.map(real, obs, dev, interface="tf")
bloch_vector_generator = qml.map(generator, obs, dev, interface="tf")

print("Real Bloch vector: {}".format(bloch_vector_real([phi, theta, omega])))
print("Generator Bloch vector: {}".format(bloch_vector_generator(gen_weights_grad.detach().numpy())))
# Out:
# Real Bloch vector: [0.90096887 0.43388374 0.        ]
# Generator Bloch vector: [0.9288218  0.36498883 0.06382172]
